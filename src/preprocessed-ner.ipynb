# %%
import pandas as pd
import numpy as np
import spacy
from spacy.language import Language
from spacy.tokens import Span
from spacy.matcher import PhraseMatcher

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/preprocessed_labelled_data.csv')

# %%
data.head()
# Out:
#                                                  NER  \
# 0  ['bite size shredded rice biscuits', 'vanilla'...
# 1  ['cream of mushroom soup', 'beef', 'sour cream...
# 2  ['frozen corn', 'pepper', 'cream cheese', 'gar...
# 3  ['graham cracker crumbs', 'powdered sugar', 'p...
# 4  ['sour cream', 'bacon', 'pepper', 'extra lean ...
#
#                                  normalized_combined
# 0  no-bake nut cookies 1 cup firmly packed brown ...
# 1  jewell ball s chicken 1 small jar chipped beef...
# 2  creamy corn 2 16 ounce package frozen corn 1 8...
# 3  reeses cup candy 1 cup peanut butter 0.75 cup ...
# 4  cheeseburger potato soup 6 baking potatoes 1 p...

# %%
len(data)
# Out:
# 1930209

# %%
data=data.head(1000)

# %%
texts = data['normalized_combined'].tolist()
type(texts)
# Out:
# list

# %%
ner_tags = data['NER'].apply(eval).tolist()
ner_tags[0]
# Out:
# ['bite size shredded rice biscuits',
#  'vanilla',
#  'brown sugar',
#  'nuts',
#  'milk',
#  'butter']

# %%
# Create a dictionary of terms
terms = {}
patterns = []
nlp = spacy.blank("en")

for tags in ner_tags:
    for tag in tags:
        if tag not in terms and tag!='mix':
            terms[tag] = {'label': 'INGREDIENT'}
            patterns.append(nlp(tag))

# Initialize the PhraseMatcher
ingredient_matcher = PhraseMatcher(nlp.vocab)  # nlp.vocab ~ A storage class for vocabulary and other data shared across a language
ingredient_matcher.add("INGREDIENT", None, *patterns)

# %%
nlp.analyze_pipes()
# Out:
# {'summary': {}, 'problems': {}, 'attrs': {}}

# %%
@Language.component("ingredient_extractor")
def ingredient_extractor(doc):
    matches = ingredient_matcher(doc)
    spans = [Span(doc, start, end, label='INGREDIENT') for match_id, start, end in matches]

    # Resolve overlaps by keeping the longest span
    filtered_spans = spacy.util.filter_spans(spans)

    doc.ents = filtered_spans
    return doc
# Add the custom component to the pipeline
nlp.add_pipe("ingredient_extractor", last=True)


import spacy
from spacy.tokens import Span
from spacy.matcher import Matcher

@Language.component("quantity_extractor")
def quantity_extractor(doc):
    matcher = Matcher(nlp.vocab)
    pattern = [
        {"LIKE_NUM": True},  # Match numbers
        {"LIKE_NUM": True, "OP": "?"},  # Match the second number (e.g., 8), but optional
        {"LOWER": {"IN": ["cup", "tablespoon", "teaspoon", "ounce", "pound", "gram", "kilogram","package", "quart", "liter", "milliliter"]}}
    ]
    matcher.add("QUANTITY", [pattern])
    matches = matcher(doc)
    spans = [Span(doc, start, end, label="QUANTITY") for match_id, start, end in matches]
    filtered_spans = spacy.util.filter_spans(spans)

    # Ensure no overlapping entities
    new_ents = [ent for ent in doc.ents if ent.label_ != "QUANTITY"]
    doc.ents = new_ents + filtered_spans
    return doc
nlp.add_pipe("quantity_extractor", last=True)
# Out:
# <function __main__.quantity_extractor(doc)>

# %%
import spacy
from spacy.tokens import Span
from spacy.matcher import Matcher
from spacy.language import Language

nlp = spacy.blank("en")

# Create a dictionary of terms
terms = {}
patterns = []

for tags in ner_tags:
    for tag in tags:
        if tag not in terms and tag!='mix':
            terms[tag] = {'label': 'INGREDIENT'}
            patterns.append(nlp(tag))

# Initialize the PhraseMatcher
ingredient_matcher = PhraseMatcher(nlp.vocab)  # nlp.vocab ~ A storage class for vocabulary and other data shared across a language
ingredient_matcher.add("INGREDIENT", None, *patterns)

# Quantity extractor component
@Language.component("quantity_extractor")
def quantity_extractor(doc):
    # Extract quantities
    matcher = Matcher(nlp.vocab)
    pattern = [
        {"LIKE_NUM": True},  # Match numbers
        {"LIKE_NUM": True, "OP": "?"},  # Match the second number (e.g., 8), but optional
        {"LOWER": {"IN": ["cup", "tablespoon", "teaspoon", "ounce", "pound", "gram", "kilogram", "package", "quart", "liter", "milliliter"]}}
    ]
    matcher.add("QUANTITY", [pattern])
    matches = matcher(doc)
    quantity_spans = [Span(doc, start, end, label="QUANTITY") for match_id, start, end in matches]

    # Ensure no duplicate spans and keep unique ones
#    seen_spans = set()
#    unique_quantity_spans = []
#    for span in quantity_spans:
#        span_text = span.text.strip()

#        if span_text not in seen_spans:
#            unique_quantity_spans.append(span)
#            seen_spans.add(span_text)

    filtered_spans = spacy.util.filter_spans(quantity_spans)
   # Filter out existing QUANTITY entities
    new_ents = [ent for ent in doc.ents if ent.label_ != "QUANTITY"]
    #print(new_ents)
    # Add the unique quantity spans to the new_ents list
    doc.ents = new_ents + filtered_spans  # Add unique quantity spans

    return doc
nlp.add_pipe("quantity_extractor", last=True)  # Quantity extractor runs first
# Out:
# <function __main__.quantity_extractor(doc)>

# %%
# Initialize the PhraseMatcher
ingredient_matcher = PhraseMatcher(nlp.vocab)  # nlp.vocab ~ A storage class for vocabulary and other data shared across a language
ingredient_matcher.add("INGREDIENT", None, *patterns)

# Ingredient extractor component
@Language.component("ingredient_extractor")
def ingredient_extractor(doc):
    # Extract ingredients after quantity extraction
    matches = ingredient_matcher(doc)
    spans = [Span(doc, start, end, label='INGREDIENT') for match_id, start, end in matches]

#    seen_spans = set()
    unique_spans = []

    # Check if the ingredient overlaps with any quantity span before adding
    quantity_spans = [ent for ent in doc.ents if ent.label_ == "QUANTITY"]

    for span in spans:
 #       span_text = span.text.strip()
        overlap_found = False

        # Check if the ingredient span overlaps with any quantity span
        for quantity in quantity_spans:
            if span.start < quantity.end and span.end > quantity.start:  # If overlap occurs
                overlap_found = True
                break  # Skip adding this ingredient if it overlaps with a quantity

        # Add ingredient span if there's no overlap with any quantity span
        if not overlap_found:
 #           if span_text not in seen_spans:
                unique_spans.append(span)
 #               seen_spans.add(span_text)

    # Resolve overlaps and filter out duplicate ingredient spans
    filtered_spans = spacy.util.filter_spans(unique_spans)
    new_ents = [ent for ent in doc.ents if ent.label_ != "INGREDIENT"]
    doc.ents = new_ents + filtered_spans  # Add unique ingredient spans, excluding overlapping ones

    return doc

# Add the custom components to the pipeline (reversed order)
nlp.add_pipe("ingredient_extractor", last=True)  # Ingredient extractor runs second
# Out:
# <function __main__.ingredient_extractor(doc)>

# %%
nlp.analyze_pipes()
# Out:
# {'summary': {'quantity_extractor': {'assigns': [],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False},
#   'ingredient_extractor': {'assigns': [],
#    'requires': [],
#    'scores': [],
#    'retokenizes': False}},
#  'problems': {'quantity_extractor': [], 'ingredient_extractor': []},
#  'attrs': {}}

# %%
from spacy.tokens import DocBin

train_data = [(text, {"entities": []}) for text in texts]

for i, (text, annotations) in enumerate(train_data):
    doc = nlp(text)
    entities = [(ent.start_char, ent.end_char, ent.label_) for ent in doc.ents]
    train_data[i] = (text, {"entities": entities})

# %%
train_data
# Out:
# [('no-bake nut cookies 1 cup firmly packed brown sugar 0.5 cup evaporated milk 0.5 teaspoon vanilla 0.5 cup broken nuts pecans 2 tablespoon butter or margarine 3.5 cup bite size shredded rice biscuits in a heavy 2 quart saucepan mix brown sugar nuts evaporated milk and butter or margarine stir over medium heat until mixture bubbles all over top boil and stir 5 minutes more take off heat stir in vanilla and cereal mix well using 2 teaspoon drop and shape into 30 clusters on wax paper let stand until firm about 30 minutes',
#   {'entities': [(20, 25, 'QUANTITY'),
#     (40, 51, 'INGREDIENT'),
#     (52, 59, 'QUANTITY'),
#     (71, 75, 'INGREDIENT'),
#     (76, 88, 'QUANTITY'),
#     (89, 96, 'INGREDIENT'),
#     (97, 104, 'QUANTITY'),
#     (112, 116, 'INGREDIENT'),
#     (117, 123, 'INGREDIENT'),
#     (124, 136, 'QUANTITY'),
#     (137, 143, 'INGREDIENT'),
#     (147, 156, 'INGREDIENT'),
#     (157, 164, 'QUANTITY'),
#     (165, 197, 'INGREDIENT'),
#     (209, 216, 'QUANTITY'),
#     (230, 241, 'INGREDIENT'),
#     (242, 246, 'INGREDIENT'),
#     (258, 262, 'INGREDIENT'),
#     (267, 273, 'INGREDIENT'),
#     (277, 286, 'INGREDIENT'),
#     (395, 402, 'INGREDIENT'),
#     (407, 413, 'INGREDIENT'),
#     (429, 439, 'QUANTITY')]}),
#  ('jewell ball s chicken 1 small jar chipped beef cut up 4 boned chicken breasts 1 can cream of mushroom soup 1 carton sour cream place chipped beef on bottom of baking dish place chicken on top of beef mix soup and cream together pour over chicken bake uncovered at 275 for 3 hours',
#   {'entities': [(14, 21, 'INGREDIENT'),
#     (42, 46, 'INGREDIENT'),
#     (62, 77, 'INGREDIENT'),
#     (84, 106, 'INGREDIENT'),
#     (116, 126, 'INGREDIENT'),
#     (141, 145, 'INGREDIENT'),
#     (177, 184, 'INGREDIENT'),
#     (195, 199, 'INGREDIENT'),
#     (213, 218, 'INGREDIENT'),
#     (238, 245, 'INGREDIENT')]}),
#  ('creamy corn 2 16 ounce package frozen corn 1 8 ounce package cream cheese cubed 0.33 cup butter cubed 0.5 teaspoon garlic powder 0.5 teaspoon salt 0.25 teaspoon pepper in a slow cooker combine all ingredients cover and cook on low for 4 hours or until heated through and cheese is melted stir well before serving yields 6 servings',
#   {'entities': [(7, 11, 'INGREDIENT'),
#     (12, 22, 'QUANTITY'),
#     (31, 42, 'INGREDIENT'),
#     (43, 52, 'QUANTITY'),
#     (61, 73, 'INGREDIENT'),
#     (80, 88, 'QUANTITY'),
#     (89, 95, 'INGREDIENT'),
#     (102, 114, 'QUANTITY'),
#     (115, 128, 'INGREDIENT'),
#     (129, 141, 'QUANTITY'),
#     (142, 146, 'INGREDIENT'),
#     (147, 160, 'QUANTITY'),
#     (161, 167, 'INGREDIENT'),
#     (271, 277, 'INGREDIENT')]}),
#  ('reeses cup candy 1 cup peanut butter 0.75 cup graham cracker crumbs 1 cup melted butter 1 pound 3.5 cup powdered sugar 1 large package chocolate chips combine first four ingredients and press in 13 x 9 inch ungreased pan melt chocolate chips and spread over mixture refrigerate for about 20 minutes and cut into pieces before chocolate gets hard keep in refrigerator',
#   {'entities': [(17, 22, 'QUANTITY'),
#     (23, 36, 'INGREDIENT'),
#     (37, 45, 'QUANTITY'),
#     (46, 67, 'INGREDIENT'),
#     (68, 73, 'QUANTITY'),
#     (81, 87, 'INGREDIENT'),
#     (88, 95, 'QUANTITY'),
#     (96, 103, 'QUANTITY'),
#     (104, 118, 'INGREDIENT'),
#     (135, 150, 'INGREDIENT'),
#     (226, 241, 'INGREDIENT'),
#     (326, 335, 'INGREDIENT')]}),
#  ('cheeseburger potato soup 6 baking potatoes 1 pound of extra lean ground beef 0.67 cup butter or margarine 6 cup milk 0.75 teaspoon salt 0.5 teaspoon pepper 1.5 cup 6 ounce shredded cheddar cheese divided 12 sliced bacon cooked crumbled and divided 4 green onion chopped and divided 1 8 ounce carton sour cream optional wash potatoes prick several times with a fork microwave them with a wet paper towel covering the potatoes on high for 6 8 minutes the potatoes should be soft ready to eat let them cool enough to handle cut in half lengthwise scoop out pulp and reserve discard shells brown ground beef until done drain any grease from the meat set aside when done meat will be added later melt butter in a large kettle over low heat add flour stirring until smooth cook 1 minute stirring constantly gradually add milk cook over medium heat stirring constantly until thickened and bubbly stir in potato ground beef salt pepper 1 cup of cheese 2 tablespoon of green onion and 0.5 cup of bacon cook until heated do not boil stir in sour cream if desired cook until heated do not boil sprinkle with remaining cheese bacon and green onions',
#   {'entities': [(13, 19, 'INGREDIENT'),
#     (27, 42, 'INGREDIENT'),
#     (43, 50, 'QUANTITY'),
#     (54, 76, 'INGREDIENT'),
#     (77, 85, 'QUANTITY'),
#     (86, 92, 'INGREDIENT'),
#     (96, 105, 'INGREDIENT'),
#     (106, 111, 'QUANTITY'),
#     (112, 116, 'INGREDIENT'),
#     (117, 130, 'QUANTITY'),
#     (131, 135, 'INGREDIENT'),
#     (136, 148, 'QUANTITY'),
#     (149, 155, 'INGREDIENT'),
#     (156, 163, 'QUANTITY'),
#     (164, 171, 'QUANTITY'),
#     (181, 195, 'INGREDIENT'),
#     (214, 219, 'INGREDIENT'),
#     (250, 261, 'INGREDIENT'),
#     (282, 291, 'QUANTITY'),
#     (299, 309, 'INGREDIENT'),
#     (324, 332, 'INGREDIENT'),
#     (416, 424, 'INGREDIENT'),
#     (453, 461, 'INGREDIENT'),
#     (477, 482, 'INGREDIENT'),
#     (579, 585, 'INGREDIENT'),
#     (592, 603, 'INGREDIENT'),
#     (625, 631, 'INGREDIENT'),
#     (696, 702, 'INGREDIENT'),
#     (739, 744, 'INGREDIENT'),
#     (815, 819, 'INGREDIENT'),
#     (897, 903, 'INGREDIENT'),
#     (904, 915, 'INGREDIENT'),
#     (916, 920, 'INGREDIENT'),
#     (921, 927, 'INGREDIENT'),
#     (928, 933, 'QUANTITY'),
#     (937, 943, 'INGREDIENT'),
#     (944, 956, 'QUANTITY'),
#     (960, 971, 'INGREDIENT'),
#     (976, 983, 'QUANTITY'),
#     (987, 992, 'INGREDIENT'),
#     (1031, 1041, 'INGREDIENT'),
#     (1107, 1113, 'INGREDIENT'),
#     (1114, 1119, 'INGREDIENT'),
#     (1124, 1136, 'INGREDIENT')]}),
#  ('rhubarb coffee cake 1.5 cup sugar 0.5 cup butter 1 egg 1 cup buttermilk 2 cup flour 0.5 teaspoon salt 1 teaspoon soda 1 cup buttermilk 2 cup rhubarb finely cut 1 teaspoon vanilla cream sugar and butter add egg and beat well to creamed butter sugar and egg add alternately buttermilk with mixture of flour salt and soda mix well add rhubarb and vanilla pour into greased 9 x 13 inch pan and add topping',
#   {'entities': [(0, 7, 'INGREDIENT'),
#     (8, 14, 'INGREDIENT'),
#     (15, 19, 'INGREDIENT'),
#     (20, 27, 'QUANTITY'),
#     (28, 33, 'INGREDIENT'),
#     (34, 41, 'QUANTITY'),
#     (42, 48, 'INGREDIENT'),
#     (51, 54, 'INGREDIENT'),
#     (55, 60, 'QUANTITY'),
#     (61, 71, 'INGREDIENT'),
#     (72, 77, 'QUANTITY'),
#     (78, 83, 'INGREDIENT'),
#     (84, 96, 'QUANTITY'),
#     (97, 101, 'INGREDIENT'),
#     (102, 112, 'QUANTITY'),
#     (113, 117, 'INGREDIENT'),
#     (118, 123, 'QUANTITY'),
#     (124, 134, 'INGREDIENT'),
#     (135, 140, 'QUANTITY'),
#     (141, 148, 'INGREDIENT'),
#     (160, 170, 'QUANTITY'),
#     (171, 178, 'INGREDIENT'),
#     (179, 184, 'INGREDIENT'),
#     (185, 190, 'INGREDIENT'),
#     (195, 201, 'INGREDIENT'),
#     (206, 209, 'INGREDIENT'),
#     (235, 241, 'INGREDIENT'),
#     (242, 247, 'INGREDIENT'),
#     (252, 255, 'INGREDIENT'),
#     (272, 282, 'INGREDIENT'),
#     (299, 304, 'INGREDIENT'),
#     (305, 309, 'INGREDIENT'),
#     (314, 318, 'INGREDIENT'),
#     (332, 339, 'INGREDIENT'),
#     (344, 351, 'INGREDIENT'),
#     (394, 401, 'INGREDIENT')]}),
#  ('scalloped corn 1 can cream-style corn 1 can whole kernel corn 0.5 package approximately 20 saltine crackers crushed 1 egg beaten 6 teaspoon butter divided pepper to taste mix together both cans of corn crackers egg 2 teaspoon of melted butter and pepper and place in a buttered baking dish dot with remaining 4 teaspoon of butter bake at 350 for 1 hour',
#   {'entities': [(10, 14, 'INGREDIENT'),
#     (21, 37, 'INGREDIENT'),
#     (44, 61, 'INGREDIENT'),
#     (62, 73, 'QUANTITY'),
#     (99, 107, 'INGREDIENT'),
#     (118, 121, 'INGREDIENT'),
#     (129, 139, 'QUANTITY'),
#     (140, 146, 'INGREDIENT'),
#     (155, 161, 'INGREDIENT'),
#     (197, 201, 'INGREDIENT'),
#     (202, 210, 'INGREDIENT'),
#     (211, 214, 'INGREDIENT'),
#     (215, 225, 'QUANTITY'),
#     (236, 242, 'INGREDIENT'),
#     (247, 253, 'INGREDIENT'),
#     (309, 319, 'QUANTITY'),
#     (323, 329, 'INGREDIENT')]}),
#  ('double cherry delight 1 17 ounce can dark sweet pitted cherries 0.5 cup ginger ale 1 6 ounce package jell-o cherry flavor gelatin 2 cup boiling water 0.12 teaspoon almond extract 1 cup miniature marshmallows drain cherries measuring syrup cut cherries in half add ginger ale and enough water to syrup to make 1.5 cup dissolve gelatin in boiling water add measured liquid and almond extract chill until very thick fold in marshmallows and the cherries spoon into 6 cup mold chill until firm at least 4 hours or overnight unmold makes about 5.33 cup',
#   {'entities': [(7, 13, 'INGREDIENT'),
#     (22, 32, 'QUANTITY'),
#     (37, 63, 'INGREDIENT'),
#     (64, 71, 'QUANTITY'),
#     (72, 82, 'INGREDIENT'),
#     (83, 92, 'QUANTITY'),
#     (108, 114, 'INGREDIENT'),
#     (115, 129, 'INGREDIENT'),
#     (130, 135, 'QUANTITY'),
#     (136, 149, 'INGREDIENT'),
#     (150, 163, 'QUANTITY'),
#     (164, 178, 'INGREDIENT'),
#     (179, 184, 'QUANTITY'),
#     (195, 207, 'INGREDIENT'),
#     (214, 222, 'INGREDIENT'),
#     (233, 238, 'INGREDIENT'),
#     (243, 251, 'INGREDIENT'),
#     (264, 274, 'INGREDIENT'),
#     (286, 291, 'INGREDIENT'),
#     (295, 300, 'INGREDIENT'),
#     (309, 316, 'QUANTITY'),
#     (326, 333, 'INGREDIENT'),
#     (337, 350, 'INGREDIENT'),
#     (364, 370, 'INGREDIENT'),
#     (375, 389, 'INGREDIENT'),
#     (421, 433, 'INGREDIENT'),
#     (442, 450, 'INGREDIENT'),
#     (462, 467, 'QUANTITY'),
#     (539, 547, 'QUANTITY')]}),
#  ('buckeye candy 1 box powdered sugar 8 ounce soft butter 1 8 ounce peanut butter paraffin 12 ounce chocolate chips mix sugar butter and peanut butter roll into balls and place on cookie sheet set in freezer for at least 30 minutes melt chocolate chips and paraffin in double boiler using a toothpick dip balls 0.75 of way into chocolate chip and paraffin mixture to make them look like buckeyes',
#   {'entities': [(20, 34, 'INGREDIENT'),
#     (35, 42, 'QUANTITY'),
#     (48, 54, 'INGREDIENT'),
#     (55, 64, 'QUANTITY'),
#     (65, 78, 'INGREDIENT'),
#     (79, 87, 'INGREDIENT'),
#     (88, 96, 'QUANTITY'),
#     (97, 112, 'INGREDIENT'),
#     (117, 122, 'INGREDIENT'),
#     (123, 129, 'INGREDIENT'),
#     (134, 147, 'INGREDIENT'),
#     (148, 152, 'INGREDIENT'),
#     (234, 249, 'INGREDIENT'),
#     (254, 262, 'INGREDIENT'),
#     (325, 334, 'INGREDIENT'),
#     (344, 352, 'INGREDIENT')]}),
#  ('quick barbecue wings chicken wings as many as you need for dinner flour barbecue sauce your choice clean wings flour and fry until done place fried chicken wings in microwave bowl stir in barbecue sauce microwave on high stir once for 4 minutes',
#   {'entities': [(21, 28, 'INGREDIENT'),
#     (66, 71, 'INGREDIENT'),
#     (72, 86, 'INGREDIENT'),
#     (87, 98, 'INGREDIENT'),
#     (111, 116, 'INGREDIENT'),
#     (148, 155, 'INGREDIENT'),
#     (175, 179, 'INGREDIENT'),
#     (188, 202, 'INGREDIENT')]}),
#  ('taco salad chip dip 8 ounce ortega taco sauce 8 ounce sour cream 8 ounce cream cheese 1 pound ground beef 1 package taco seasoning shredded lettuce 1 large diced tomato 1 medium diced onion 1 large diced green pepper shredded colby or cheddar cheese mix taco sauce sour cream and cream cheese spread on pizza pan brown meat drain off fat and add taco seasoning spread over cream mixture layer with raw vegetables top with cheese serve with chips',
#   {'entities': [(0, 4, 'INGREDIENT'),
#     (5, 10, 'INGREDIENT'),
#     (20, 27, 'QUANTITY'),
#     (35, 45, 'INGREDIENT'),
#     (46, 53, 'QUANTITY'),
#     (54, 64, 'INGREDIENT'),
#     (65, 72, 'QUANTITY'),
#     (73, 85, 'INGREDIENT'),
#     (86, 93, 'QUANTITY'),
#     (94, 105, 'INGREDIENT'),
#     (106, 115, 'QUANTITY'),
#     (116, 130, 'INGREDIENT'),
#     (131, 147, 'INGREDIENT'),
#     (162, 168, 'INGREDIENT'),
#     (184, 189, 'INGREDIENT'),
#     (204, 216, 'INGREDIENT'),
#     (235, 249, 'INGREDIENT'),
#     (254, 264, 'INGREDIENT'),
#     (265, 275, 'INGREDIENT'),
#     (280, 292, 'INGREDIENT'),
#     (303, 308, 'INGREDIENT'),
#     (334, 337, 'INGREDIENT'),
#     (346, 360, 'INGREDIENT'),
#     (373, 378, 'INGREDIENT'),
#     (387, 392, 'INGREDIENT'),
#     (422, 428, 'INGREDIENT'),
#     (440, 445, 'INGREDIENT')]}),
#  ('fresh strawberry pie 1 baked pie shell 1 quart cleaned strawberries 1.5 cup water 4 tablespoon cornstarch 1 cup sugar 0.12 teaspoon salt 4 tablespoon strawberry jello mix water cornstarch sugar and salt in saucepan stir constantly and boil until thick and clear remove from heat and stir in jello set aside to cool but don t allow it to set layer strawberries in baked crust pour cooled glaze over continue layering berries and glaze refrigerate serve with whipped cream',
#   {'entities': [(6, 16, 'INGREDIENT'),
#     (29, 38, 'INGREDIENT'),
#     (39, 46, 'QUANTITY'),
#     (47, 67, 'INGREDIENT'),
#     (68, 75, 'QUANTITY'),
#     (76, 81, 'INGREDIENT'),
#     (82, 94, 'QUANTITY'),
#     (95, 105, 'INGREDIENT'),
#     (106, 111, 'QUANTITY'),
#     (112, 117, 'INGREDIENT'),
#     (118, 131, 'QUANTITY'),
#     (132, 136, 'INGREDIENT'),
#     (137, 149, 'QUANTITY'),
#     (150, 166, 'INGREDIENT'),
#     (171, 176, 'INGREDIENT'),
#     (177, 187, 'INGREDIENT'),
#     (188, 193, 'INGREDIENT'),
#     (198, 202, 'INGREDIENT'),
#     (291, 296, 'INGREDIENT'),
#     (341, 346, 'INGREDIENT'),
#     (347, 359, 'INGREDIENT'),
#     (369, 374, 'INGREDIENT'),
#     (457, 470, 'INGREDIENT')]}),
#  ('easy german chocolate cake 0.5 package chocolate fudge cake mix without pudding or 1 jiffy mix 0.5 package white cake mix without pudding or 1 jiffy mix 0.25 cup wesson oil mix according to directions and add oil bake in 9 x 13 inch pan',
#   {'entities': [(12, 26, 'INGREDIENT'),
#     (27, 38, 'QUANTITY'),
#     (39, 59, 'INGREDIENT'),
#     (95, 106, 'QUANTITY'),
#     (107, 121, 'INGREDIENT'),
#     (153, 161, 'QUANTITY'),
#     (162, 172, 'INGREDIENT'),
#     (209, 212, 'INGREDIENT')]}),
#  ('broccoli salad 1 large head broccoli about 1.5 pound 10 slices bacon cooked and crumbled 5 green onions sliced or 0.25 cup chopped red onion 0.5 cup raisins 1 cup mayonnaise 2 tablespoon vinegar 0.25 cup sugar trim off large leaves of broccoli and remove the tough ends of lower stalks wash the broccoli thoroughly cut the florets and stems into bite-size pieces place in a large bowl add bacon onions and raisins combine remaining ingredients stirring well add dressing to broccoli mixture and toss gently cover and refrigerate 2 to 3 hours makes about 6 servings',
#   {'entities': [(0, 8, 'INGREDIENT'),
#     (9, 14, 'INGREDIENT'),
#     (28, 36, 'INGREDIENT'),
#     (43, 52, 'QUANTITY'),
#     (63, 68, 'INGREDIENT'),
#     (91, 103, 'INGREDIENT'),
#     (114, 122, 'QUANTITY'),
#     (131, 140, 'INGREDIENT'),
#     (141, 148, 'QUANTITY'),
#     (149, 156, 'INGREDIENT'),
#     (157, 162, 'QUANTITY'),
#     (163, 173, 'INGREDIENT'),
#     (174, 186, 'QUANTITY'),
#     (187, 194, 'INGREDIENT'),
#     (195, 203, 'QUANTITY'),
#     (204, 209, 'INGREDIENT'),
#     (235, 243, 'INGREDIENT'),
#     (295, 303, 'INGREDIENT'),
#     (346, 350, 'INGREDIENT'),
#     (380, 384, 'INGREDIENT'),
#     (389, 394, 'INGREDIENT'),
#     (395, 401, 'INGREDIENT'),
#     (406, 413, 'INGREDIENT'),
#     (462, 470, 'INGREDIENT'),
#     (474, 482, 'INGREDIENT')]}),
#  ('strawberry whatever 1 pound frozen strawberries in juice 1 small can crushed pineapple 3 ripe bananas 1 cup chopped pecans 1 large package strawberry jell-o 1.5 cup boiling water 1 pt sour cream mix jell-o in boiling water add strawberries pineapple crushed bananas and nuts spread 0.5 mixture in 13 x 6.5 inch pan allow to gel in freezer 30 minutes add layer of sour cream then remaining mixture on top gel and serve',
#   {'entities': [(0, 10, 'INGREDIENT'),
#     (20, 27, 'QUANTITY'),
#     (28, 47, 'INGREDIENT'),
#     (77, 86, 'INGREDIENT'),
#     (94, 101, 'INGREDIENT'),
#     (102, 107, 'QUANTITY'),
#     (116, 122, 'INGREDIENT'),
#     (139, 156, 'INGREDIENT'),
#     (157, 164, 'QUANTITY'),
#     (165, 178, 'INGREDIENT'),
#     (184, 194, 'INGREDIENT'),
#     (209, 222, 'INGREDIENT'),
#     (227, 239, 'INGREDIENT'),
#     (240, 249, 'INGREDIENT'),
#     (258, 265, 'INGREDIENT'),
#     (270, 274, 'INGREDIENT'),
#     (354, 359, 'INGREDIENT'),
#     (363, 373, 'INGREDIENT')]}),
#  ('eggless milkless applesauce cake 0.75 cup sugar 0.5 cup shortening 1.5 cup applesauce 3 level teaspoon soda 1 teaspoon each cinnamon cloves and nutmeg 2 cup sifted flour 1 cup raisins 1 cup nuts mix crisco with applesauce nuts and raisins sift dry ingredients and add mix well put in a greased and floured loaf pan or tube pan bake in loaf pan at 350 to 375 for 45 to 60 minutes layer pan at 375 for 20 minutes or tube pan at 325 for 1 hour',
#   {'entities': [(17, 27, 'INGREDIENT'),
#     (28, 32, 'INGREDIENT'),
#     (33, 41, 'QUANTITY'),
#     (42, 47, 'INGREDIENT'),
#     (48, 55, 'QUANTITY'),
#     (56, 66, 'INGREDIENT'),
#     (67, 74, 'QUANTITY'),
#     (75, 85, 'INGREDIENT'),
#     (88, 93, 'INGREDIENT'),
#     (103, 107, 'INGREDIENT'),
#     (108, 118, 'QUANTITY'),
#     (124, 132, 'INGREDIENT'),
#     (133, 139, 'INGREDIENT'),
#     (144, 150, 'INGREDIENT'),
#     (151, 156, 'QUANTITY'),
#     (164, 169, 'INGREDIENT'),
#     (170, 175, 'QUANTITY'),
#     (176, 183, 'INGREDIENT'),
#     (184, 189, 'QUANTITY'),
#     (190, 194, 'INGREDIENT'),
#     (199, 205, 'INGREDIENT'),
#     (211, 221, 'INGREDIENT'),
#     (222, 226, 'INGREDIENT'),
#     (231, 238, 'INGREDIENT'),
#     (379, 384, 'INGREDIENT')]}),
#  ('grandma hanrath s banana breadfort collins colorado 1 cup sugar 0.5 cup shortening 2 eggs add one at a time 1 teaspoon salt 2 teaspoon soda 2 cup flour 0.25 cup nuts 2 over-ripe bananas chopped cream sugar and shortening add eggs salt and soda then bananas and flour add nuts mix well bake in loaf pan at 350 for 1 hour',
#   {'entities': [(18, 24, 'INGREDIENT'),
#     (52, 57, 'QUANTITY'),
#     (58, 63, 'INGREDIENT'),
#     (64, 71, 'QUANTITY'),
#     (72, 82, 'INGREDIENT'),
#     (85, 89, 'INGREDIENT'),
#     (108, 118, 'QUANTITY'),
#     (119, 123, 'INGREDIENT'),
#     (124, 134, 'QUANTITY'),
#     (135, 139, 'INGREDIENT'),
#     (140, 145, 'QUANTITY'),
#     (146, 151, 'INGREDIENT'),
#     (152, 160, 'QUANTITY'),
#     (161, 165, 'INGREDIENT'),
#     (178, 185, 'INGREDIENT'),
#     (194, 199, 'INGREDIENT'),
#     (200, 205, 'INGREDIENT'),
#     (210, 220, 'INGREDIENT'),
#     (225, 229, 'INGREDIENT'),
#     (230, 234, 'INGREDIENT'),
#     (239, 243, 'INGREDIENT'),
#     (249, 256, 'INGREDIENT'),
#     (261, 266, 'INGREDIENT'),
#     (271, 275, 'INGREDIENT')]}),
#  ('chocolate frango mints 1 package devil s food cake mix 1 package chocolate fudge pudding mix instant 8 ounce sour cream 0.75 cup water 0.5 cup wesson oil 4 eggs 6 ounce chopped frango mints mix ingredients together for 5 minutes scrape bowl often last fold in chocolate chip mints bake at 350 for 35 to 40 minutes or until done cake mix directions',
#   {'entities': [(0, 9, 'INGREDIENT'),
#     (10, 16, 'INGREDIENT'),
#     (23, 32, 'QUANTITY'),
#     (41, 45, 'INGREDIENT'),
#     (46, 54, 'INGREDIENT'),
#     (55, 64, 'QUANTITY'),
#     (65, 88, 'INGREDIENT'),
#     (101, 108, 'QUANTITY'),
#     (109, 119, 'INGREDIENT'),
#     (120, 128, 'QUANTITY'),
#     (129, 134, 'INGREDIENT'),
#     (135, 142, 'QUANTITY'),
#     (143, 153, 'INGREDIENT'),
#     (156, 160, 'INGREDIENT'),
#     (161, 168, 'QUANTITY'),
#     (177, 183, 'INGREDIENT'),
#     (236, 240, 'INGREDIENT'),
#     (260, 269, 'INGREDIENT'),
#     (328, 336, 'INGREDIENT')]}),
#  ('spaghetti sauce to can 0.5 bushel tomatoes 1 cup oil 0.25 cup minced garlic 6 cans tomato paste 3 peppers 2 sweet and 1 hot 1.5 cup sugar 0.5 cup salt 1 tablespoon sweet basil 2 tablespoon oregano 1 teaspoon italian seasoning cook ground or chopped peppers and onions in oil for 0.5 hour cook tomatoes and garlic as for juice put through the mill i use a food processor and do my tomatoes uncooked i then add the garlic right to the juice add peppers and onions to juice and remainder of ingredients cook approximately 1 hour put in jars and seal yields 7 quart',
#   {'entities': [(0, 15, 'INGREDIENT'),
#     (34, 42, 'INGREDIENT'),
#     (43, 48, 'QUANTITY'),
#     (49, 52, 'INGREDIENT'),
#     (53, 61, 'QUANTITY'),
#     (69, 75, 'INGREDIENT'),
#     (83, 95, 'INGREDIENT'),
#     (98, 105, 'INGREDIENT'),
#     (124, 131, 'QUANTITY'),
#     (132, 137, 'INGREDIENT'),
#     (138, 145, 'QUANTITY'),
#     (146, 150, 'INGREDIENT'),
#     (151, 163, 'QUANTITY'),
#     (164, 175, 'INGREDIENT'),
#     (176, 188, 'QUANTITY'),
#     (189, 196, 'INGREDIENT'),
#     (197, 207, 'QUANTITY'),
#     (208, 225, 'INGREDIENT'),
#     (231, 237, 'INGREDIENT'),
#     (249, 256, 'INGREDIENT'),
#     (261, 267, 'INGREDIENT'),
#     (271, 274, 'INGREDIENT'),
#     (293, 301, 'INGREDIENT'),
#     (306, 312, 'INGREDIENT'),
#     (355, 359, 'INGREDIENT'),
#     (380, 388, 'INGREDIENT'),
#     (413, 419, 'INGREDIENT'),
#     (443, 450, 'INGREDIENT'),
#     (455, 461, 'INGREDIENT'),
#     (554, 561, 'QUANTITY')]}),
#  ('prize-winning meat loaf 1.5 pound ground beef 1 cup tomato juice 0.75 cup oats uncooked 1 egg beaten 0.25 cup chopped onion 0.25 teaspoon pepper 1.5 teaspoon salt mix well press firmly into an 8.5 x 4.5 x 2.5 inch loaf pan bake in preheated moderate oven bake at 350 for 1 hour let stand 5 minutes before slicing makes 8 servings',
#   {'entities': [(24, 33, 'QUANTITY'),
#     (34, 45, 'INGREDIENT'),
#     (46, 51, 'QUANTITY'),
#     (52, 64, 'INGREDIENT'),
#     (65, 73, 'QUANTITY'),
#     (74, 78, 'INGREDIENT'),
#     (90, 93, 'INGREDIENT'),
#     (101, 109, 'QUANTITY'),
#     (118, 123, 'INGREDIENT'),
#     (124, 137, 'QUANTITY'),
#     (138, 144, 'INGREDIENT'),
#     (145, 157, 'QUANTITY'),
#     (158, 162, 'INGREDIENT')]}),
#  ('smothered round steak servings 4 2 pound round steak 0.5 teaspoon ground black pepper 1 teaspoon ground white pepper 0.5 cup vegetable oil 2 bell peppers chopped 1 cup beef stock or water 2 teaspoon salt 1 teaspoon ground red pepper all-purpose flour dredging 3 medium onions chopped 1 celery rib chopped alex patout says smothering is a multipurpose cajun technique that works wonders with everything from game to snap beans it s similar to what the rest of the world knows as braising the ingredients are briefly browned or sauteed then cooked with a little liquid over a low heat for a long time',
#   {'entities': [(16, 21, 'INGREDIENT'),
#     (31, 40, 'QUANTITY'),
#     (47, 52, 'INGREDIENT'),
#     (53, 65, 'QUANTITY'),
#     (66, 85, 'INGREDIENT'),
#     (86, 96, 'QUANTITY'),
#     (97, 116, 'INGREDIENT'),
#     (117, 124, 'QUANTITY'),
#     (125, 138, 'INGREDIENT'),
#     (141, 153, 'INGREDIENT'),
#     (162, 167, 'QUANTITY'),
#     (168, 178, 'INGREDIENT'),
#     (182, 187, 'INGREDIENT'),
#     (188, 198, 'QUANTITY'),
#     (199, 203, 'INGREDIENT'),
#     (204, 214, 'QUANTITY'),
#     (215, 232, 'INGREDIENT'),
#     (233, 250, 'INGREDIENT'),
#     (269, 275, 'INGREDIENT'),
#     (286, 292, 'INGREDIENT'),
#     (420, 425, 'INGREDIENT'),
#     (560, 566, 'INGREDIENT'),
#     (589, 593, 'INGREDIENT')]}),
#  ('corral barbecued beef steak strips 2 pound round steak 0.5 to 0.75 inch thick sliced in strips 0.12 inch thick or thinner and 3.5 to 4 inches long easily sliced if partially frozen 2 tablespoon cooking oil 1 can 15 ounce tomato sauce 0.33 cup water 2 tablespoon brown sugar 1 tablespoon prepared mustard 1 tablespoon worcestershire sauce 1 medium sized onion thinly sliced brown strips in cooking oil pour off drippings combine tomato sauce water brown sugar mustard and worcestershire sauce add sauce and onion to meat slices cover and cook slowly stirring occasionally 30 minutes or until meat is tender serve over rice or buttered noodles yields 6 to 8 servings',
#   {'entities': [(17, 21, 'INGREDIENT'),
#     (22, 27, 'INGREDIENT'),
#     (35, 42, 'QUANTITY'),
#     (49, 54, 'INGREDIENT'),
#     (142, 146, 'INGREDIENT'),
#     (174, 180, 'INGREDIENT'),
#     (181, 193, 'QUANTITY'),
#     (194, 205, 'INGREDIENT'),
#     (212, 220, 'QUANTITY'),
#     (221, 233, 'INGREDIENT'),
#     (234, 242, 'QUANTITY'),
#     (243, 248, 'INGREDIENT'),
#     (249, 261, 'QUANTITY'),
#     (262, 273, 'INGREDIENT'),
#     (274, 286, 'QUANTITY'),
#     (296, 303, 'INGREDIENT'),
#     (304, 316, 'QUANTITY'),
#     (317, 337, 'INGREDIENT'),
#     (353, 358, 'INGREDIENT'),
#     (389, 400, 'INGREDIENT'),
#     (428, 440, 'INGREDIENT'),
#     (441, 446, 'INGREDIENT'),
#     (447, 458, 'INGREDIENT'),
#     (459, 466, 'INGREDIENT'),
#     (471, 491, 'INGREDIENT'),
#     (496, 501, 'INGREDIENT'),
#     (506, 511, 'INGREDIENT'),
#     (617, 621, 'INGREDIENT'),
#     (634, 641, 'INGREDIENT')]}),
#  ('easy fudge 1 14 ounce can sweetened condensed milk 1 12 ounce package semi-sweet chocolate chips 1 1 ounce sq unsweetened chocolate if desired 1.5 cup chopped nuts if desired 1 teaspoon vanilla butter a square pan 8 x 8 x 2 inches heat milk chocolate chips and unsweetened chocolate over low heat stirring constantly until chocolate is melted and mixture is smooth remove from heat stir in nuts and vanilla spread in pan',
#   {'entities': [(11, 21, 'QUANTITY'),
#     (36, 50, 'INGREDIENT'),
#     (51, 61, 'QUANTITY'),
#     (70, 96, 'INGREDIENT'),
#     (97, 106, 'QUANTITY'),
#     (110, 131, 'INGREDIENT'),
#     (143, 150, 'QUANTITY'),
#     (159, 163, 'INGREDIENT'),
#     (175, 185, 'QUANTITY'),
#     (186, 193, 'INGREDIENT'),
#     (194, 200, 'INGREDIENT'),
#     (236, 250, 'INGREDIENT'),
#     (251, 256, 'INGREDIENT'),
#     (261, 282, 'INGREDIENT'),
#     (323, 332, 'INGREDIENT'),
#     (390, 394, 'INGREDIENT'),
#     (399, 406, 'INGREDIENT')]}),
#  ('taco-filled green pepper 1 pound ground beef 1 package taco seasoning 1 san kidney beans 1 onion chopped 1 cup salsa 4 green peppers 1 medium tomato chopped 0.5 cup cheddar cheese shredded 0.5 cup sour cream in a large skillet brown the ground beef drain stir in taco mix kidney beans and salsa bring to a boil reduce heat and let simmer for about 5 minutes cut peppers in half and clean it put peppers in boiling water for 3 minutes- drain- spoon the meat mixture into the green pepper put pepper in an ungreased pan cover and bake at 350 degrees for 15 to 20 minutes or until peppers are crispy and filling is heated through top with tomatoes cheese and sour cream',
#   {'entities': [(0, 4, 'INGREDIENT'),
#     (12, 24, 'INGREDIENT'),
#     (25, 32, 'QUANTITY'),
#     (33, 44, 'INGREDIENT'),
#     (45, 54, 'QUANTITY'),
#     (55, 69, 'INGREDIENT'),
#     (76, 88, 'INGREDIENT'),
#     (91, 96, 'INGREDIENT'),
#     (105, 110, 'QUANTITY'),
#     (111, 116, 'INGREDIENT'),
#     (119, 132, 'INGREDIENT'),
#     (142, 148, 'INGREDIENT'),
#     (157, 164, 'QUANTITY'),
#     (165, 179, 'INGREDIENT'),
#     (189, 196, 'QUANTITY'),
#     (197, 207, 'INGREDIENT'),
#     (237, 248, 'INGREDIENT'),
#     (263, 267, 'INGREDIENT'),
#     (272, 284, 'INGREDIENT'),
#     (289, 294, 'INGREDIENT'),
#     (362, 369, 'INGREDIENT'),
#     (395, 402, 'INGREDIENT'),
#     (406, 419, 'INGREDIENT'),
#     (474, 486, 'INGREDIENT'),
#     (491, 497, 'INGREDIENT'),
#     (578, 585, 'INGREDIENT'),
#     (636, 644, 'INGREDIENT'),
#     (645, 651, 'INGREDIENT'),
#     (656, 666, 'INGREDIENT')]}),
#  ('one hour rolls 1 cup milk 2 tablespoon sugar 1 package dry yeast 1 tablespoon salt 3 tablespoon crisco oil 2 cup plain flour put flour into a large mixing bowl combine sugar milk salt and oil in a saucepan and heat to boiling remove from heat and let cool to lukewarm add yeast and mix well pour into flour and stir batter will be sticky roll out batter on a floured board and cut with biscuit cutter lightly brush tops with melted oleo and fold over place rolls on a cookie sheet put in a warm place and let rise for 1 hour bake at 350 for about 20 minutes yield 2.5 dozen',
#   {'entities': [(9, 14, 'INGREDIENT'),
#     (15, 20, 'QUANTITY'),
#     (21, 25, 'INGREDIENT'),
#     (26, 38, 'QUANTITY'),
#     (39, 44, 'INGREDIENT'),
#     (45, 54, 'QUANTITY'),
#     (59, 64, 'INGREDIENT'),
#     (65, 77, 'QUANTITY'),
#     (78, 82, 'INGREDIENT'),
#     (83, 95, 'QUANTITY'),
#     (96, 106, 'INGREDIENT'),
#     (107, 112, 'QUANTITY'),
#     (119, 124, 'INGREDIENT'),
#     (129, 134, 'INGREDIENT'),
#     (155, 159, 'INGREDIENT'),
#     (168, 173, 'INGREDIENT'),
#     (174, 178, 'INGREDIENT'),
#     (179, 183, 'INGREDIENT'),
#     (188, 191, 'INGREDIENT'),
#     (272, 277, 'INGREDIENT'),
#     (301, 306, 'INGREDIENT'),
#     (338, 342, 'INGREDIENT'),
#     (432, 436, 'INGREDIENT'),
#     (457, 462, 'INGREDIENT')]}),
#  ('punch bowl fruit salad 2 large cans sliced peaches 2 large cans fruit cocktail 1 large can diced pineapple 1 quart fresh strawberries 2 red apples 2 yellow apples 4 large ripe bananas 1 pound white grapes 1 pound purple grapes in a 6 quart punch bowl mix all of the cans of fruit juice and all clean and slice berries wash and slice apples leave peeling on apples dice apples slice bananas wash and cut grapes in half mix all together nuts or other fruit may be added',
#   {'entities': [(6, 10, 'INGREDIENT'),
#     (17, 22, 'INGREDIENT'),
#     (43, 50, 'INGREDIENT'),
#     (64, 78, 'INGREDIENT'),
#     (97, 106, 'INGREDIENT'),
#     (107, 114, 'QUANTITY'),
#     (115, 133, 'INGREDIENT'),
#     (136, 146, 'INGREDIENT'),
#     (149, 162, 'INGREDIENT'),
#     (176, 183, 'INGREDIENT'),
#     (184, 191, 'QUANTITY'),
#     (192, 204, 'INGREDIENT'),
#     (205, 212, 'QUANTITY'),
#     (213, 226, 'INGREDIENT'),
#     (232, 239, 'QUANTITY'),
#     (246, 250, 'INGREDIENT'),
#     (333, 339, 'INGREDIENT'),
#     (357, 363, 'INGREDIENT'),
#     (369, 375, 'INGREDIENT'),
#     (382, 389, 'INGREDIENT'),
#     (403, 409, 'INGREDIENT'),
#     (435, 439, 'INGREDIENT')]}),
#  ('summer chicken 1 package chicken cutlets 0.5 cup oil 0.33 cup red vinegar 2 tablespoon oregano 2 tablespoon garlic salt double recipe for more chicken',
#   {'entities': [(7, 14, 'INGREDIENT'),
#     (15, 24, 'QUANTITY'),
#     (25, 40, 'INGREDIENT'),
#     (41, 48, 'QUANTITY'),
#     (49, 52, 'INGREDIENT'),
#     (53, 61, 'QUANTITY'),
#     (62, 73, 'INGREDIENT'),
#     (74, 86, 'QUANTITY'),
#     (87, 94, 'INGREDIENT'),
#     (95, 107, 'QUANTITY'),
#     (108, 119, 'INGREDIENT'),
#     (143, 150, 'INGREDIENT')]}),
#  ('cherry pizza 2 cans cherry pie mix 1 box deluxe white cake mix 1 stick butter 1 cup ground nuts grease a 9 x 12 inch cake pan spread cherry pie mix sift cake mix and spread it dry over the cherries top with ground nuts melt butter and pour over top bake 45 minutes in a 350 oven',
#   {'entities': [(0, 6, 'INGREDIENT'),
#     (7, 12, 'INGREDIENT'),
#     (20, 34, 'INGREDIENT'),
#     (41, 62, 'INGREDIENT'),
#     (71, 77, 'INGREDIENT'),
#     (78, 83, 'QUANTITY'),
#     (84, 95, 'INGREDIENT'),
#     (96, 102, 'INGREDIENT'),
#     (117, 121, 'INGREDIENT'),
#     (133, 147, 'INGREDIENT'),
#     (153, 161, 'INGREDIENT'),
#     (189, 197, 'INGREDIENT'),
#     (207, 218, 'INGREDIENT'),
#     (224, 230, 'INGREDIENT')]}),
#  ('tuna macaroni casserole 1 box macaroni and cheese 1 can tuna drained 1 small jar pimentos 1 medium onion chopped prepare macaroni and cheese as directed add drained tuna pimento and onion mix serve hot or cold',
#   {'entities': [(0, 4, 'INGREDIENT'),
#     (5, 13, 'INGREDIENT'),
#     (30, 38, 'INGREDIENT'),
#     (43, 49, 'INGREDIENT'),
#     (56, 60, 'INGREDIENT'),
#     (81, 89, 'INGREDIENT'),
#     (99, 104, 'INGREDIENT'),
#     (121, 129, 'INGREDIENT'),
#     (134, 140, 'INGREDIENT'),
#     (165, 169, 'INGREDIENT'),
#     (170, 177, 'INGREDIENT'),
#     (182, 187, 'INGREDIENT'),
#     (205, 209, 'INGREDIENT')]}),
#  ('artichoke dip 2 cans or jars artichoke hearts 1 cup mayonnaise 1 cup parmesan cheese drain artichokes and chop mix with mayonnaise and parmesan cheese after well mixed bake uncovered for 20 to 30 minutes at 350 serve with crackers',
#   {'entities': [(39, 45, 'INGREDIENT'),
#     (46, 51, 'QUANTITY'),
#     (52, 62, 'INGREDIENT'),
#     (63, 68, 'QUANTITY'),
#     (69, 84, 'INGREDIENT'),
#     (91, 101, 'INGREDIENT'),
#     (120, 130, 'INGREDIENT'),
#     (135, 150, 'INGREDIENT'),
#     (222, 230, 'INGREDIENT')]}),
#  ('broccoli dip for crackers 16 ounce sour cream 1 package dry vegetable soup mix 10 ounce package frozen chopped broccoli thawed and drained 4 to 6 ounce cheddar cheese grated mix together sour cream soup mix broccoli and half of cheese sprinkle remaining cheese on top bake at 350 for 30 minutes uncovered serve hot with vegetable crackers',
#   {'entities': [(0, 8, 'INGREDIENT'),
#     (17, 25, 'INGREDIENT'),
#     (26, 34, 'QUANTITY'),
#     (35, 45, 'INGREDIENT'),
#     (46, 55, 'QUANTITY'),
#     (60, 78, 'INGREDIENT'),
#     (79, 87, 'QUANTITY'),
#     (96, 102, 'INGREDIENT'),
#     (111, 119, 'INGREDIENT'),
#     (144, 151, 'QUANTITY'),
#     (152, 166, 'INGREDIENT'),
#     (187, 197, 'INGREDIENT'),
#     (207, 215, 'INGREDIENT'),
#     (228, 234, 'INGREDIENT'),
#     (254, 260, 'INGREDIENT'),
#     (330, 338, 'INGREDIENT')]}),
#  ('pear-lime salad 1 16 ounce can pear halves undrained 1 3 ounce package lime gelatin 1 8 ounce package cream cheese softened 1 8 ounce carton lemon yogurt drain pears reserving juice bring juice to a boil stirring constantly remove from heat add gelatin stirring until dissolved let cool slightly coarsely chop pear halves combine cream cheese and yogurt beat at medium speed of electric mixer until smooth add gelatin and beat well stir in pears pour into an oiled 4 cup mold or pyrex dish chill',
#   {'entities': [(5, 9, 'INGREDIENT'),
#     (10, 15, 'INGREDIENT'),
#     (16, 26, 'QUANTITY'),
#     (31, 42, 'INGREDIENT'),
#     (53, 62, 'QUANTITY'),
#     (71, 83, 'INGREDIENT'),
#     (84, 93, 'QUANTITY'),
#     (102, 114, 'INGREDIENT'),
#     (124, 133, 'QUANTITY'),
#     (141, 153, 'INGREDIENT'),
#     (245, 252, 'INGREDIENT'),
#     (310, 321, 'INGREDIENT'),
#     (330, 342, 'INGREDIENT'),
#     (347, 353, 'INGREDIENT'),
#     (410, 417, 'INGREDIENT'),
#     (465, 470, 'QUANTITY')]}),
#  ('watermelon rind pickles 7 pound watermelon rind 7 cup sugar 2 cup apple vinegar 0.5 teaspoon oil of cloves 0.5 teaspoon oil of cinnamon trim off green and pink parts of watermelon rind cut to 1 inch cubes parboil until tender but not soft drain combine sugar vinegar oil of cloves and oil of cinnamon bring to boiling and pour over rind let stand overnight in the morning drain off syrup heat and put over rind the third morning heat rind and syrup seal in hot sterilized jars makes 8 pints oil of cinnamon and clove keeps rind clear and transparent',
#   {'entities': [(0, 15, 'INGREDIENT'),
#     (24, 31, 'QUANTITY'),
#     (32, 47, 'INGREDIENT'),
#     (48, 53, 'QUANTITY'),
#     (54, 59, 'INGREDIENT'),
#     (60, 65, 'QUANTITY'),
#     (66, 79, 'INGREDIENT'),
#     (80, 92, 'QUANTITY'),
#     (93, 96, 'INGREDIENT'),
#     (100, 106, 'INGREDIENT'),
#     (107, 119, 'QUANTITY'),
#     (120, 135, 'INGREDIENT'),
#     (145, 150, 'INGREDIENT'),
#     (169, 184, 'INGREDIENT'),
#     (253, 258, 'INGREDIENT'),
#     (259, 266, 'INGREDIENT'),
#     (267, 270, 'INGREDIENT'),
#     (274, 280, 'INGREDIENT'),
#     (285, 300, 'INGREDIENT'),
#     (382, 387, 'INGREDIENT'),
#     (443, 448, 'INGREDIENT'),
#     (491, 506, 'INGREDIENT')]}),
#  ('chicken stew 3 pound chicken boiled 4 medium potatoes diced 2 medium onions chopped 1 16 ounce can creamed corn 1 16 ounce can english peas 1 16 ounce can field peas 1 16 ounce can butter beans 1 16 ounce can tomatoes 1 46 ounce can tomato juice 1 small box macaroni 1 tablespoon black pepper 1 tablespoon salt 1 tablespoon sugar remove chicken from bone use the broth mix the vegetables and macaroni add sugar salt and black pepper cook until all vegetables are tender over medium heat',
#   {'entities': [(0, 7, 'INGREDIENT'),
#     (13, 20, 'QUANTITY'),
#     (21, 28, 'INGREDIENT'),
#     (45, 53, 'INGREDIENT'),
#     (69, 75, 'INGREDIENT'),
#     (84, 94, 'QUANTITY'),
#     (107, 111, 'INGREDIENT'),
#     (112, 122, 'QUANTITY'),
#     (127, 139, 'INGREDIENT'),
#     (140, 150, 'QUANTITY'),
#     (161, 165, 'INGREDIENT'),
#     (166, 176, 'QUANTITY'),
#     (181, 193, 'INGREDIENT'),
#     (194, 204, 'QUANTITY'),
#     (209, 217, 'INGREDIENT'),
#     (218, 228, 'QUANTITY'),
#     (233, 245, 'INGREDIENT'),
#     (258, 266, 'INGREDIENT'),
#     (267, 279, 'QUANTITY'),
#     (280, 292, 'INGREDIENT'),
#     (293, 305, 'QUANTITY'),
#     (306, 310, 'INGREDIENT'),
#     (311, 323, 'QUANTITY'),
#     (324, 329, 'INGREDIENT'),
#     (337, 344, 'INGREDIENT'),
#     (363, 372, 'INGREDIENT'),
#     (392, 400, 'INGREDIENT'),
#     (405, 410, 'INGREDIENT'),
#     (411, 415, 'INGREDIENT'),
#     (420, 432, 'INGREDIENT')]}),
#  ('quick coffee cake 6 servings 3 tablespoon softened butter or margarine 0.5 cup granulated sugar 1 egg 1 cup flour 1.25 teaspoon baking powder 0.25 teaspoon salt 0.33 cup milk 0.25 teaspoon vanilla 0.33 cup brown sugar packed 0.5 teaspoon cinnamon 2 tablespoon butter or margarine mix 3 tablespoon fat with granulated sugar add egg and beat until creamy mix flour baking powder and salt thoroughly add to sugar mixture alternately with milk add vanilla spread batter evenly in a greased 8 inch square baking pan mix brown sugar and cinnamon and sprinkle over batter dot with 2 tablespoon fat bake at 350 moderate oven for 25 to 30 minutes',
#   {'entities': [(6, 12, 'INGREDIENT'),
#     (13, 17, 'INGREDIENT'),
#     (29, 41, 'QUANTITY'),
#     (51, 57, 'INGREDIENT'),
#     (61, 70, 'INGREDIENT'),
#     (71, 78, 'QUANTITY'),
#     (79, 95, 'INGREDIENT'),
#     (98, 101, 'INGREDIENT'),
#     (102, 107, 'QUANTITY'),
#     (108, 113, 'INGREDIENT'),
#     (114, 127, 'QUANTITY'),
#     (128, 141, 'INGREDIENT'),
#     (142, 155, 'QUANTITY'),
#     (156, 160, 'INGREDIENT'),
#     (161, 169, 'QUANTITY'),
#     (170, 174, 'INGREDIENT'),
#     (175, 188, 'QUANTITY'),
#     (189, 196, 'INGREDIENT'),
#     (197, 205, 'QUANTITY'),
#     (206, 217, 'INGREDIENT'),
#     (225, 237, 'QUANTITY'),
#     (238, 246, 'INGREDIENT'),
#     (247, 259, 'QUANTITY'),
#     (260, 266, 'INGREDIENT'),
#     (270, 279, 'INGREDIENT'),
#     (284, 296, 'QUANTITY'),
#     (297, 300, 'INGREDIENT'),
#     (306, 322, 'INGREDIENT'),
#     (327, 330, 'INGREDIENT'),
#     (357, 362, 'INGREDIENT'),
#     (363, 376, 'INGREDIENT'),
#     (381, 385, 'INGREDIENT'),
#     (404, 409, 'INGREDIENT'),
#     (435, 439, 'INGREDIENT'),
#     (444, 451, 'INGREDIENT'),
#     (515, 526, 'INGREDIENT'),
#     (531, 539, 'INGREDIENT'),
#     (574, 586, 'QUANTITY'),
#     (587, 590, 'INGREDIENT')]}),
#  ('angel biscuits 5 cup flour 3 tablespoon sugar 4 teaspoon baking powder 1.5 package dry yeast 2 cup buttermilk 1 teaspoon soda 1.5 sticks margarine 0.5 cup warm water mix flour sugar baking powder soda and salt together cut in margarine dissolve yeast in warm water stir into buttermilk and add to dry mixture cover and chill',
#   {'entities': [(0, 5, 'INGREDIENT'),
#     (6, 14, 'INGREDIENT'),
#     (15, 20, 'QUANTITY'),
#     (21, 26, 'INGREDIENT'),
#     (27, 39, 'QUANTITY'),
#     (40, 45, 'INGREDIENT'),
#     (46, 56, 'QUANTITY'),
#     (57, 70, 'INGREDIENT'),
#     (71, 82, 'QUANTITY'),
#     (87, 92, 'INGREDIENT'),
#     (93, 98, 'QUANTITY'),
#     (99, 109, 'INGREDIENT'),
#     (110, 120, 'QUANTITY'),
#     (121, 125, 'INGREDIENT'),
#     (137, 146, 'INGREDIENT'),
#     (147, 154, 'QUANTITY'),
#     (155, 165, 'INGREDIENT'),
#     (170, 175, 'INGREDIENT'),
#     (176, 181, 'INGREDIENT'),
#     (182, 195, 'INGREDIENT'),
#     (196, 200, 'INGREDIENT'),
#     (205, 209, 'INGREDIENT'),
#     (226, 235, 'INGREDIENT'),
#     (245, 250, 'INGREDIENT'),
#     (254, 264, 'INGREDIENT'),
#     (275, 285, 'INGREDIENT')]}),
#  ('quick peppermint puffs 8 marshmallows 2 tablespoon margarine melted 0.25 cup crushed peppermint candy 1 can crescent rolls dip marshmallows in melted margarine roll in candy wrap a crescent triangle around each marshmallow completely covering the marshmallow and square edges of dough tightly to seal dip in margarine and place in a greased muffin tin bake at 375 for 10 to 15 minutes remove from pan',
#   {'entities': [(25, 37, 'INGREDIENT'),
#     (38, 50, 'QUANTITY'),
#     (51, 60, 'INGREDIENT'),
#     (68, 76, 'QUANTITY'),
#     (85, 101, 'INGREDIENT'),
#     (108, 122, 'INGREDIENT'),
#     (127, 139, 'INGREDIENT'),
#     (150, 159, 'INGREDIENT'),
#     (160, 164, 'INGREDIENT'),
#     (308, 317, 'INGREDIENT')]}),
#  ('fruit pizza 1 box yellow cake mix 0.25 cup water 0.25 cup brown sugar 0.5 cup soft butter 2 eggs 0.5 cup chopped nuts mix ingredients and spread into 2 greased pizza pans bake at 350 for 15 20 minutes',
#   {'entities': [(6, 11, 'INGREDIENT'),
#     (18, 33, 'INGREDIENT'),
#     (34, 42, 'QUANTITY'),
#     (43, 48, 'INGREDIENT'),
#     (49, 57, 'QUANTITY'),
#     (58, 69, 'INGREDIENT'),
#     (70, 77, 'QUANTITY'),
#     (83, 89, 'INGREDIENT'),
#     (92, 96, 'INGREDIENT'),
#     (97, 104, 'QUANTITY'),
#     (113, 117, 'INGREDIENT'),
#     (160, 165, 'INGREDIENT')]}),
#  ('chocolate mint bars 1 cup flour 1 cup sugar 0.5 cup oleo softened 4 eggs 1 can chocolate syrup mix together and bake in 9 x 13 inch pan at 350 for 25 to 30 minutes top should spring back when touched lightly do not overbake cool completely then spread with mint layer',
#   {'entities': [(0, 9, 'INGREDIENT'),
#     (20, 25, 'QUANTITY'),
#     (26, 31, 'INGREDIENT'),
#     (32, 37, 'QUANTITY'),
#     (38, 43, 'INGREDIENT'),
#     (44, 51, 'QUANTITY'),
#     (52, 56, 'INGREDIENT'),
#     (68, 72, 'INGREDIENT'),
#     (79, 94, 'INGREDIENT'),
#     (262, 267, 'INGREDIENT')]}),
#  ('beer bread 3 cup self rising flour 1 12 ounce can beer 1 tablespoon sugar stir the ingredients together and put in a greased and floured loaf pan bake at 425 degrees for 50 minutes drizzle melted butter on top',
#   {'entities': [(0, 4, 'INGREDIENT'),
#     (5, 10, 'INGREDIENT'),
#     (11, 16, 'QUANTITY'),
#     (29, 34, 'INGREDIENT'),
#     (35, 45, 'QUANTITY'),
#     (50, 54, 'INGREDIENT'),
#     (55, 67, 'QUANTITY'),
#     (68, 73, 'INGREDIENT'),
#     (196, 202, 'INGREDIENT')]}),
#  ('chicken divan 0.25 cup margarine 0.25 cup chopped onion or as much as you want chopped celery to taste 0.25 cup flour 0.12 teaspoon curry powder 1 can sliced mushrooms save juice 1 can cream of celery soup 1 package chopped broccoli 1 cubed chicken shredded monterey jack cheese melt margarine in skillet saute onions and celery remove from heat stir in flour and curry powder drain mushrooms and keep juice add water to juice to make 0.5 cup liquid stir liquid and soup into flour mixture add mushrooms cook until thick arrange broccoli and cubed chicken in a large baking dish spoon sauce over chicken top with grated cheese bake in a 350 oven for about 20 minutes or in microwave until cheese is melted',
#   {'entities': [(0, 7, 'INGREDIENT'),
#     (14, 22, 'QUANTITY'),
#     (23, 32, 'INGREDIENT'),
#     (33, 41, 'QUANTITY'),
#     (50, 55, 'INGREDIENT'),
#     (87, 93, 'INGREDIENT'),
#     (103, 111, 'QUANTITY'),
#     (112, 117, 'INGREDIENT'),
#     (118, 131, 'QUANTITY'),
#     (132, 144, 'INGREDIENT'),
#     (158, 167, 'INGREDIENT'),
#     (185, 205, 'INGREDIENT'),
#     (206, 215, 'QUANTITY'),
#     (224, 232, 'INGREDIENT'),
#     (241, 248, 'INGREDIENT'),
#     (249, 278, 'INGREDIENT'),
#     (284, 293, 'INGREDIENT'),
#     (311, 317, 'INGREDIENT'),
#     (322, 328, 'INGREDIENT'),
#     (354, 359, 'INGREDIENT'),
#     (364, 376, 'INGREDIENT'),
#     (383, 392, 'INGREDIENT'),
#     (412, 417, 'INGREDIENT'),
#     (435, 442, 'QUANTITY'),
#     (443, 449, 'INGREDIENT'),
#     (455, 461, 'INGREDIENT'),
#     (476, 481, 'INGREDIENT'),
#     (494, 503, 'INGREDIENT'),
#     (529, 537, 'INGREDIENT'),
#     (548, 555, 'INGREDIENT'),
#     (585, 590, 'INGREDIENT'),
#     (596, 603, 'INGREDIENT'),
#     (613, 626, 'INGREDIENT'),
#     (689, 695, 'INGREDIENT')]}),
#  ('mexican cookie rings 1.5 cup sifted flour 0.5 teaspoon baking powder 0.5 teaspoon salt 0.5 cup butter 0.67 cup sugar 3 egg yolks 1 teaspoon vanilla multi-colored candies sift flour baking powder and salt together cream together butter and sugar add egg yolks and vanilla beat until light and fluffy mix in sifted dry ingredients shape into 1 inch balls push wooden spoon handle through center twist shape into rings dip each cookie into candies place on lightly greased baking sheets bake in 375 oven for 10 to 12 minutes or until golden brown cool on racks serves 2 dozen',
#   {'entities': [(21, 28, 'QUANTITY'),
#     (36, 41, 'INGREDIENT'),
#     (42, 54, 'QUANTITY'),
#     (55, 68, 'INGREDIENT'),
#     (69, 81, 'QUANTITY'),
#     (82, 86, 'INGREDIENT'),
#     (87, 94, 'QUANTITY'),
#     (95, 101, 'INGREDIENT'),
#     (102, 110, 'QUANTITY'),
#     (111, 116, 'INGREDIENT'),
#     (119, 128, 'INGREDIENT'),
#     (129, 139, 'QUANTITY'),
#     (140, 147, 'INGREDIENT'),
#     (148, 169, 'INGREDIENT'),
#     (175, 180, 'INGREDIENT'),
#     (181, 194, 'INGREDIENT'),
#     (199, 203, 'INGREDIENT'),
#     (213, 218, 'INGREDIENT'),
#     (228, 234, 'INGREDIENT'),
#     (239, 244, 'INGREDIENT'),
#     (249, 258, 'INGREDIENT'),
#     (263, 270, 'INGREDIENT'),
#     (282, 287, 'INGREDIENT'),
#     (437, 444, 'INGREDIENT')]}),
#  ('vegetable-burger soup 0.5 pound ground beef 2 cup water 1 teaspoon sugar 1 package cup-a-soup onion soup mix dry 1 pound can stewed tomatoes 1 8 ounce can tomato sauce 1 10 ounce package frozen mixed vegetables lightly brown beef in soup pot drain off excess fat stir in tomatoes tomato sauce water frozen vegetables soup mix and sugar bring to a boil reduce heat and simmer for 20 minutes serve',
#   {'entities': [(22, 31, 'QUANTITY'),
#     (32, 43, 'INGREDIENT'),
#     (44, 49, 'QUANTITY'),
#     (50, 55, 'INGREDIENT'),
#     (56, 66, 'QUANTITY'),
#     (67, 72, 'INGREDIENT'),
#     (73, 82, 'QUANTITY'),
#     (94, 108, 'INGREDIENT'),
#     (113, 120, 'QUANTITY'),
#     (132, 140, 'INGREDIENT'),
#     (141, 150, 'QUANTITY'),
#     (155, 167, 'INGREDIENT'),
#     (168, 178, 'QUANTITY'),
#     (187, 210, 'INGREDIENT'),
#     (225, 229, 'INGREDIENT'),
#     (259, 262, 'INGREDIENT'),
#     (271, 279, 'INGREDIENT'),
#     (280, 292, 'INGREDIENT'),
#     (293, 298, 'INGREDIENT'),
#     (299, 305, 'INGREDIENT'),
#     (330, 335, 'INGREDIENT')]}),
#  ('chicken ole 4 chicken breasts cooked 1 can cream of chicken soup 1 can cream of mushroom soup 1 can green chili salsa sauce 1 can green chilies 1 cup milk 1 grated onion 1 package corn tortilla in pieces dice chicken mix all ingredients together let sit overnight bake 1.5 hours at 375',
#   {'entities': [(0, 7, 'INGREDIENT'),
#     (14, 29, 'INGREDIENT'),
#     (43, 64, 'INGREDIENT'),
#     (71, 93, 'INGREDIENT'),
#     (100, 123, 'INGREDIENT'),
#     (130, 143, 'INGREDIENT'),
#     (144, 149, 'QUANTITY'),
#     (150, 154, 'INGREDIENT'),
#     (164, 169, 'INGREDIENT'),
#     (170, 179, 'QUANTITY'),
#     (180, 193, 'INGREDIENT'),
#     (209, 216, 'INGREDIENT')]}),
#  ('creamy coleslaw better homes and gardens 4 cup shredded cabbage 0.5 cup shredded carrots 0.25 cup finely chopped green pepper 2 tablespoon finely chopped onion 0.5 cup mayonnaise 1 tablespoon vinegar 2 teaspoon sugar 1 teaspoon celery seed 0.25 teaspoon salt in a large bowl combine cabbage carrot green pepper and onion or can use package of slaw mix purchased from store',
#   {'entities': [(41, 46, 'QUANTITY'),
#     (56, 63, 'INGREDIENT'),
#     (64, 71, 'QUANTITY'),
#     (81, 88, 'INGREDIENT'),
#     (89, 97, 'QUANTITY'),
#     (113, 125, 'INGREDIENT'),
#     (126, 138, 'QUANTITY'),
#     (154, 159, 'INGREDIENT'),
#     (160, 167, 'QUANTITY'),
#     (168, 178, 'INGREDIENT'),
#     (179, 191, 'QUANTITY'),
#     (192, 199, 'INGREDIENT'),
#     (200, 210, 'QUANTITY'),
#     (211, 216, 'INGREDIENT'),
#     (217, 227, 'QUANTITY'),
#     (228, 234, 'INGREDIENT'),
#     (240, 253, 'QUANTITY'),
#     (254, 258, 'INGREDIENT'),
#     (270, 274, 'INGREDIENT'),
#     (283, 290, 'INGREDIENT'),
#     (291, 297, 'INGREDIENT'),
#     (298, 310, 'INGREDIENT'),
#     (315, 320, 'INGREDIENT')]}),
#  ('creole flounder 2 pound flounder or pollack fillets 1.5 cup chopped tomatoes 0.5 cup chopped green pepper 0.33 cup lemon juice 1 tablespoon salad oil 2 teaspoon salt 2 teaspoon minced onion 1 teaspoon basil leaves 0.25 teaspoon coarsely ground black pepper 4 drops red pepper sauce green pepper rings heat oven to 500 place fillets in single layer in baking dish 13.5 x 9 x 2 inch stir together remaining ingredients except pepper rings spoon over fillets bake 5 to 8 minutes or until fish flakes easily with fork remove fillets to warm platter garnish with green pepper rings makes 4 to 6 servings',
#   {'entities': [(7, 15, 'INGREDIENT'),
#     (16, 23, 'QUANTITY'),
#     (24, 32, 'INGREDIENT'),
#     (52, 59, 'QUANTITY'),
#     (68, 76, 'INGREDIENT'),
#     (77, 84, 'QUANTITY'),
#     (93, 105, 'INGREDIENT'),
#     (106, 114, 'QUANTITY'),
#     (115, 126, 'INGREDIENT'),
#     (127, 139, 'QUANTITY'),
#     (140, 149, 'INGREDIENT'),
#     (150, 160, 'QUANTITY'),
#     (161, 165, 'INGREDIENT'),
#     (166, 176, 'QUANTITY'),
#     (184, 189, 'INGREDIENT'),
#     (190, 200, 'QUANTITY'),
#     (201, 206, 'INGREDIENT'),
#     (214, 227, 'QUANTITY'),
#     (237, 256, 'INGREDIENT'),
#     (259, 281, 'INGREDIENT'),
#     (282, 294, 'INGREDIENT'),
#     (342, 347, 'INGREDIENT'),
#     (424, 430, 'INGREDIENT'),
#     (558, 570, 'INGREDIENT')]}),
# ...
#     (203, 210, 'INGREDIENT'),
#     (211, 219, 'QUANTITY'),
#     (228, 233, 'INGREDIENT'),
#     (234, 247, 'QUANTITY'),
#     (248, 254, 'INGREDIENT'),
#     (255, 263, 'QUANTITY'),
#     (264, 269, 'INGREDIENT'),
#     (270, 275, 'QUANTITY'),
#     (282, 285, 'INGREDIENT'),
#     (306, 311, 'INGREDIENT'),
#     (323, 327, 'INGREDIENT'),
#     (332, 338, 'INGREDIENT'),
#     (403, 409, 'INGREDIENT'),
#     (418, 423, 'INGREDIENT'),
#     (429, 433, 'INGREDIENT'),
#     (513, 527, 'INGREDIENT'),
#     (575, 578, 'INGREDIENT')]}),
#  ('cheese patties with pecans 0.5 pound sharp cheese 1 stick butter 1.5 cup flour 0.75 teaspoon salt pecans grate cheese and mix with softened butter add flour and salt work mixture with hands until it firms up shape into long roll wrap in waxed paper refrigerate cut as for icebox cookies put pecan pieces on top bake at 400 for 10 minutes',
#   {'entities': [(0, 6, 'INGREDIENT'),
#     (20, 26, 'INGREDIENT'),
#     (27, 36, 'QUANTITY'),
#     (37, 49, 'INGREDIENT'),
#     (58, 64, 'INGREDIENT'),
#     (65, 72, 'QUANTITY'),
#     (73, 78, 'INGREDIENT'),
#     (79, 92, 'QUANTITY'),
#     (93, 97, 'INGREDIENT'),
#     (98, 104, 'INGREDIENT'),
#     (111, 117, 'INGREDIENT'),
#     (140, 146, 'INGREDIENT'),
#     (151, 156, 'INGREDIENT'),
#     (161, 165, 'INGREDIENT'),
#     (219, 223, 'INGREDIENT'),
#     (224, 228, 'INGREDIENT'),
#     (291, 296, 'INGREDIENT')]}),
#  ('crab spread appetizer 8 ounce cream cheese 1 tablespoon mayonnaise 1 tablespoon worcestershire sauce 1 teaspoon lemon juice garlic to taste parsley flakes 1 pound cooked shrimp or crab flakes cocktail sauce mix all ingredients except parsley shrimp or crab and cocktail sauce spread on glass plate top with cocktail sauce and shrimp or crab sprinkle with parsley serve with chips or crackers',
#   {'entities': [(0, 4, 'INGREDIENT'),
#     (22, 29, 'QUANTITY'),
#     (30, 42, 'INGREDIENT'),
#     (43, 55, 'QUANTITY'),
#     (56, 66, 'INGREDIENT'),
#     (67, 79, 'QUANTITY'),
#     (80, 100, 'INGREDIENT'),
#     (101, 111, 'QUANTITY'),
#     (112, 123, 'INGREDIENT'),
#     (124, 130, 'INGREDIENT'),
#     (140, 154, 'INGREDIENT'),
#     (155, 162, 'QUANTITY'),
#     (170, 176, 'INGREDIENT'),
#     (180, 184, 'INGREDIENT'),
#     (192, 206, 'INGREDIENT'),
#     (234, 241, 'INGREDIENT'),
#     (242, 248, 'INGREDIENT'),
#     (252, 256, 'INGREDIENT'),
#     (261, 275, 'INGREDIENT'),
#     (307, 321, 'INGREDIENT'),
#     (326, 332, 'INGREDIENT'),
#     (336, 340, 'INGREDIENT'),
#     (355, 362, 'INGREDIENT'),
#     (374, 379, 'INGREDIENT'),
#     (383, 391, 'INGREDIENT')]}),
#  ('crispy baked onion rings 2 large sweet onions 1 7 ounce package corn flakes 1 teaspoon seasoned salt 2 teaspoon sugar 1 teaspoon paprika 1 cup egg substitute cut onions into rings combine cereal salt sugar and paprika divide in half beat egg at high speed with electric mixer until soft peaks form dip onion in egg dredge in crumb mixture place in single layer on baking sheet coated with vegetable cooking spray bake at 375 for 15 minutes until crispy good and low-fat',
#   {'entities': [(13, 18, 'INGREDIENT'),
#     (33, 45, 'INGREDIENT'),
#     (46, 55, 'QUANTITY'),
#     (64, 75, 'INGREDIENT'),
#     (76, 86, 'QUANTITY'),
#     (96, 100, 'INGREDIENT'),
#     (101, 111, 'QUANTITY'),
#     (112, 117, 'INGREDIENT'),
#     (118, 128, 'QUANTITY'),
#     (129, 136, 'INGREDIENT'),
#     (137, 142, 'QUANTITY'),
#     (143, 157, 'INGREDIENT'),
#     (162, 168, 'INGREDIENT'),
#     (188, 194, 'INGREDIENT'),
#     (195, 199, 'INGREDIENT'),
#     (200, 205, 'INGREDIENT'),
#     (210, 217, 'INGREDIENT'),
#     (238, 241, 'INGREDIENT'),
#     (302, 307, 'INGREDIENT'),
#     (311, 314, 'INGREDIENT'),
#     (355, 360, 'INGREDIENT'),
#     (389, 412, 'INGREDIENT'),
#     (466, 469, 'INGREDIENT')]}),
#  ('peanut butter rice krispie bars 1 cup chunky peanut butter 0.5 cup sugar 0.5 cup white corn syrup karo 2 cup rice krispies cereal 1 small package chocolate chips cream together peanut butter sugar and corn syrup add rice krispies and put in an 8 x 8 inch pan press down top with chocolate chip pieces and place in heated oven until chocolate melts spread with knife cool and cut into serving pieces',
#   {'entities': [(0, 13, 'INGREDIENT'),
#     (14, 18, 'INGREDIENT'),
#     (32, 37, 'QUANTITY'),
#     (38, 58, 'INGREDIENT'),
#     (59, 66, 'QUANTITY'),
#     (67, 72, 'INGREDIENT'),
#     (73, 80, 'QUANTITY'),
#     (81, 97, 'INGREDIENT'),
#     (103, 108, 'QUANTITY'),
#     (109, 122, 'INGREDIENT'),
#     (123, 129, 'INGREDIENT'),
#     (146, 161, 'INGREDIENT'),
#     (162, 167, 'INGREDIENT'),
#     (177, 190, 'INGREDIENT'),
#     (191, 196, 'INGREDIENT'),
#     (201, 211, 'INGREDIENT'),
#     (216, 229, 'INGREDIENT'),
#     (279, 288, 'INGREDIENT'),
#     (332, 341, 'INGREDIENT')]}),
#  ('unusual oatmeal cookies 1 cup shortening 2 cup brown sugar 2 eggs 1 tablespoon vanilla 2 cup flour 2 teaspoon baking powder 0.5 teaspoon cinnamon 0.5 teaspoon baking soda 1 teaspoon salt 2 cup coconut 1.5 cup chopped nuts 1.5 cup oatmeal cream shortening and sugar add eggs and vanilla beat well sift flour baking powder soda cinnamon and salt add gradually stir in oatmeal coconut and nuts beat well drop by teaspoonful on cookie sheets bake at 350 for 12 to 15 minutes makes 5 dozen',
#   {'entities': [(8, 15, 'INGREDIENT'),
#     (24, 29, 'QUANTITY'),
#     (30, 40, 'INGREDIENT'),
#     (41, 46, 'QUANTITY'),
#     (47, 58, 'INGREDIENT'),
#     (61, 65, 'INGREDIENT'),
#     (66, 78, 'QUANTITY'),
#     (79, 86, 'INGREDIENT'),
#     (87, 92, 'QUANTITY'),
#     (93, 98, 'INGREDIENT'),
#     (99, 109, 'QUANTITY'),
#     (110, 123, 'INGREDIENT'),
#     (124, 136, 'QUANTITY'),
#     (137, 145, 'INGREDIENT'),
#     (146, 158, 'QUANTITY'),
#     (159, 170, 'INGREDIENT'),
#     (171, 181, 'QUANTITY'),
#     (182, 186, 'INGREDIENT'),
#     (187, 192, 'QUANTITY'),
#     (193, 200, 'INGREDIENT'),
#     (201, 208, 'QUANTITY'),
#     (217, 221, 'INGREDIENT'),
#     (222, 229, 'QUANTITY'),
#     (230, 237, 'INGREDIENT'),
#     (238, 243, 'INGREDIENT'),
#     (244, 254, 'INGREDIENT'),
#     (259, 264, 'INGREDIENT'),
#     (269, 273, 'INGREDIENT'),
#     (278, 285, 'INGREDIENT'),
#     (301, 306, 'INGREDIENT'),
#     (307, 320, 'INGREDIENT'),
#     (321, 325, 'INGREDIENT'),
#     (326, 334, 'INGREDIENT'),
#     (339, 343, 'INGREDIENT'),
#     (366, 373, 'INGREDIENT'),
#     (374, 381, 'INGREDIENT'),
#     (386, 390, 'INGREDIENT')]}),
#  ('salad soup 1 small clove garlic or garlic salt 1 tablespoon sugar 1.5 teaspoon salt 1 large can v-8 vegetable juice 0.25 cup salad oil 2 tablespoon lemon juice 1 teaspoon worcestershire sauce 3 tomatoes finely diced 1 cucumber about 1.5 cup finely diced 1 green pepper finely diced 1 cup shredded carrots 1 cup thinly sliced celery 0.25 cup thinly sliced green onion can use chopped white onions mix first 7 ingredients in a blender stir in remaining ingredients chill at least 1 hour before serving keeps for weeks in refrigerator',
#   {'entities': [(0, 5, 'INGREDIENT'),
#     (19, 31, 'INGREDIENT'),
#     (35, 46, 'INGREDIENT'),
#     (47, 59, 'QUANTITY'),
#     (60, 65, 'INGREDIENT'),
#     (66, 78, 'QUANTITY'),
#     (79, 83, 'INGREDIENT'),
#     (100, 115, 'INGREDIENT'),
#     (116, 124, 'QUANTITY'),
#     (125, 134, 'INGREDIENT'),
#     (135, 147, 'QUANTITY'),
#     (148, 159, 'INGREDIENT'),
#     (160, 170, 'QUANTITY'),
#     (171, 191, 'INGREDIENT'),
#     (194, 202, 'INGREDIENT'),
#     (218, 226, 'INGREDIENT'),
#     (233, 240, 'QUANTITY'),
#     (256, 268, 'INGREDIENT'),
#     (282, 287, 'QUANTITY'),
#     (297, 304, 'INGREDIENT'),
#     (305, 310, 'QUANTITY'),
#     (325, 331, 'INGREDIENT'),
#     (332, 340, 'QUANTITY'),
#     (355, 366, 'INGREDIENT'),
#     (383, 388, 'INGREDIENT'),
#     (389, 395, 'INGREDIENT')]}),
#  ('christmas cheer punch 3 large bottles ginger ale 3 large bottles lemon-lime soda 12 red maraschino cherries 1 firm orange sliced 12 green maraschino cherries chill ginger ale and soda in bottles in refrigerator pour part of ginger ale and lemon-lime in separate ice cube trays place a green or red cherry or orange slice in each cube freeze as quickly as possible when ready to serve put cubes in chilled punch bowl and pour in chilled carbonated beverages place bowl in bed of christmas greens or other appropriate decoration yields 30 servings',
#   {'entities': [(38, 48, 'INGREDIENT'),
#     (65, 80, 'INGREDIENT'),
#     (84, 107, 'INGREDIENT'),
#     (115, 121, 'INGREDIENT'),
#     (132, 137, 'INGREDIENT'),
#     (138, 157, 'INGREDIENT'),
#     (164, 174, 'INGREDIENT'),
#     (179, 183, 'INGREDIENT'),
#     (224, 234, 'INGREDIENT'),
#     (239, 244, 'INGREDIENT'),
#     (245, 249, 'INGREDIENT'),
#     (285, 290, 'INGREDIENT'),
#     (294, 297, 'INGREDIENT'),
#     (298, 304, 'INGREDIENT'),
#     (308, 320, 'INGREDIENT'),
#     (369, 374, 'INGREDIENT'),
#     (411, 415, 'INGREDIENT'),
#     (463, 467, 'INGREDIENT'),
#     (488, 494, 'INGREDIENT')]}),
#  ('fresh cranberry-orange relish 1 navel orange unpeeled and cut into small chunks 1 bag cranberries 12 ounce 0.75 cup granulated sugar process all ingredients in food processor using on off turns until finely chopped cover and chill at least 1 hour makes 3 cup 12 servings',
#   {'entities': [(16, 22, 'INGREDIENT'),
#     (38, 44, 'INGREDIENT'),
#     (86, 97, 'INGREDIENT'),
#     (98, 106, 'QUANTITY'),
#     (107, 115, 'QUANTITY'),
#     (116, 132, 'INGREDIENT'),
#     (160, 164, 'INGREDIENT'),
#     (253, 258, 'QUANTITY')]}),
#  ('may muffins 1 cup self-rising flour 3 tablespoon mayonnaise 0.5 cup buttermilk mix lightly bake in greased muffin pan for 15 to 20 minutes in a 425 preheated oven yields 10 to 12 muffins',
#   {'entities': [(4, 11, 'INGREDIENT'),
#     (12, 17, 'QUANTITY'),
#     (30, 35, 'INGREDIENT'),
#     (36, 48, 'QUANTITY'),
#     (49, 59, 'INGREDIENT'),
#     (60, 67, 'QUANTITY'),
#     (68, 78, 'INGREDIENT'),
#     (179, 186, 'INGREDIENT')]}),
#  ('quick salmon casserole 1 7.75 ounce can salmon 1 10 ounce can condensed cream of mushroom soup 0.25 cup liquid liquid from canned salmon plus milk to volume 1.5 cup cooked or canned peas 1 cup unbroken potato chips drain and flake salmon and save liquid in a 1 quart greased casserole combine soup liquid peas and salmon top with potato chips place in a moderately hot oven 375 and bake for 30 minutes or until bubbling hot makes 4 to 6 servings this is very delicious',
#   {'entities': [(6, 12, 'INGREDIENT'),
#     (23, 35, 'QUANTITY'),
#     (40, 46, 'INGREDIENT'),
#     (47, 57, 'QUANTITY'),
#     (72, 94, 'INGREDIENT'),
#     (95, 103, 'QUANTITY'),
#     (104, 110, 'INGREDIENT'),
#     (111, 117, 'INGREDIENT'),
#     (130, 136, 'INGREDIENT'),
#     (142, 146, 'INGREDIENT'),
#     (157, 164, 'QUANTITY'),
#     (182, 186, 'INGREDIENT'),
#     (187, 192, 'QUANTITY'),
#     (202, 208, 'INGREDIENT'),
#     (209, 214, 'INGREDIENT'),
#     (231, 237, 'INGREDIENT'),
#     (247, 253, 'INGREDIENT'),
#     (259, 266, 'QUANTITY'),
#     (298, 304, 'INGREDIENT'),
#     (305, 309, 'INGREDIENT'),
#     (314, 320, 'INGREDIENT'),
#     (330, 336, 'INGREDIENT'),
#     (337, 342, 'INGREDIENT')]}),
#  ('tofu foo yong 2 tablespoon water 1 cup snow peas cut in 1 inch pieces 8 green onions cut in 1.5 inch pieces 8 ounce can sliced water chestnuts 2 cup fresh bean sprouts 1.75 pound tofu 2 tablespoon soy sauce 0.5 cup mashed tofu 3 tablespoon unbleached flour 0.75 cup yeast flakes 2 tablespoon chicken-style seasoning saute snow peas green onions and chestnuts in water over low heat for 5 minutes when vegetables are crisp-tender mix in sprouts remove from heat and set aside',
#   {'entities': [(0, 4, 'INGREDIENT'),
#     (14, 26, 'QUANTITY'),
#     (27, 32, 'INGREDIENT'),
#     (33, 38, 'QUANTITY'),
#     (39, 48, 'INGREDIENT'),
#     (72, 84, 'INGREDIENT'),
#     (108, 115, 'QUANTITY'),
#     (127, 142, 'INGREDIENT'),
#     (143, 148, 'QUANTITY'),
#     (149, 167, 'INGREDIENT'),
#     (168, 178, 'QUANTITY'),
#     (179, 183, 'INGREDIENT'),
#     (184, 196, 'QUANTITY'),
#     (197, 206, 'INGREDIENT'),
#     (207, 214, 'QUANTITY'),
#     (215, 226, 'INGREDIENT'),
#     (227, 239, 'QUANTITY'),
#     (251, 256, 'INGREDIENT'),
#     (257, 265, 'QUANTITY'),
#     (266, 271, 'INGREDIENT'),
#     (279, 291, 'QUANTITY'),
#     (292, 305, 'INGREDIENT'),
#     (306, 315, 'INGREDIENT'),
#     (322, 331, 'INGREDIENT'),
#     (332, 344, 'INGREDIENT'),
#     (362, 367, 'INGREDIENT')]}),
#  ('cheese cake 1 pound ricotta cheese low-fat 3 3 ounce package cream cheese softened low-fat 1 cup sugar 4 eggs slightly beaten 0.33 cup cornstarch 2 tablespoon lemon juice 1 teaspoon vanilla 0.5 cup melted butter or oleo 1 pt sour cream low-fat grease spring-form pan with butter dust with graham cracker crumbs beat cream cheese and ricotta until creamy blend in sugar and eggs add cornstarch lemon juice and vanilla until blended add melted butter and sour cream and blend well pour into a 10 inch spring-form pan up to top ring bake in preheated 250 oven for about 1.5 hours until firm around edges turn off heat and leave in oven for 2 hours cool on rack then put in refrigerator until morning remove sides of pan top with any topping you wish or eat plain',
#   {'entities': [(0, 6, 'INGREDIENT'),
#     (7, 11, 'INGREDIENT'),
#     (12, 19, 'QUANTITY'),
#     (20, 34, 'INGREDIENT'),
#     (39, 42, 'INGREDIENT'),
#     (43, 52, 'QUANTITY'),
#     (61, 73, 'INGREDIENT'),
#     (87, 90, 'INGREDIENT'),
#     (91, 96, 'QUANTITY'),
#     (97, 102, 'INGREDIENT'),
#     (105, 109, 'INGREDIENT'),
#     (126, 134, 'QUANTITY'),
#     (135, 145, 'INGREDIENT'),
#     (146, 158, 'QUANTITY'),
#     (159, 170, 'INGREDIENT'),
#     (171, 181, 'QUANTITY'),
#     (182, 189, 'INGREDIENT'),
#     (190, 197, 'QUANTITY'),
#     (205, 211, 'INGREDIENT'),
#     (215, 219, 'INGREDIENT'),
#     (225, 235, 'INGREDIENT'),
#     (240, 243, 'INGREDIENT'),
#     (244, 250, 'INGREDIENT'),
#     (272, 278, 'INGREDIENT'),
#     (289, 310, 'INGREDIENT'),
#     (316, 328, 'INGREDIENT'),
#     (333, 340, 'INGREDIENT'),
#     (363, 368, 'INGREDIENT'),
#     (373, 377, 'INGREDIENT'),
#     (382, 392, 'INGREDIENT'),
#     (393, 404, 'INGREDIENT'),
#     (409, 416, 'INGREDIENT'),
#     (442, 448, 'INGREDIENT'),
#     (453, 463, 'INGREDIENT'),
#     (730, 737, 'INGREDIENT')]}),
#  ('m m cookies 1 cup shortening 1 cup brown sugar 0.5 cup sugar 2 teaspoon vanilla 1.5 cup m m s or chocolate chips 2 eggs 2.25 cup flour 1 teaspoon baking soda 1 teaspoon salt blend shortening brown and white sugar in bowl beat in vanilla and eggs sift remaining dry ingredients together add to sugar egg mixture blending well stir in m m s bake at 325 for 10 minutes',
#   {'entities': [(12, 17, 'QUANTITY'),
#     (18, 28, 'INGREDIENT'),
#     (29, 34, 'QUANTITY'),
#     (35, 46, 'INGREDIENT'),
#     (47, 54, 'QUANTITY'),
#     (55, 60, 'INGREDIENT'),
#     (61, 71, 'QUANTITY'),
#     (72, 79, 'INGREDIENT'),
#     (80, 87, 'QUANTITY'),
#     (97, 112, 'INGREDIENT'),
#     (115, 119, 'INGREDIENT'),
#     (120, 128, 'QUANTITY'),
#     (129, 134, 'INGREDIENT'),
#     (135, 145, 'QUANTITY'),
#     (146, 157, 'INGREDIENT'),
#     (158, 168, 'QUANTITY'),
#     (169, 173, 'INGREDIENT'),
#     (180, 190, 'INGREDIENT'),
#     (201, 212, 'INGREDIENT'),
#     (216, 220, 'INGREDIENT'),
#     (229, 236, 'INGREDIENT'),
#     (241, 245, 'INGREDIENT'),
#     (293, 298, 'INGREDIENT'),
#     (299, 302, 'INGREDIENT')]}),
#  ('chickpea spread on baguette 16 ounce can chickpeas 8 ounce sour cream 1 small clove garlic pressed 0.5 teaspoon salt 0.5 teaspoon pepper 0.5 tablespoon sweet paprika 1 cup grated monterey jack cheese baguette crush chickpeas leaving some chunkiness to them stir in sour cream add rest of ingredients except cheese slice baguette on an angle spread with chickpea mixture top with shredded cheese place on baking sheet bake at 350 for 20 minutes place under broiler for a couple minutes until cheese is bubbly and browning',
#   {'entities': [(19, 27, 'INGREDIENT'),
#     (28, 36, 'QUANTITY'),
#     (41, 50, 'INGREDIENT'),
#     (51, 58, 'QUANTITY'),
#     (59, 69, 'INGREDIENT'),
#     (78, 90, 'INGREDIENT'),
#     (99, 111, 'QUANTITY'),
#     (112, 116, 'INGREDIENT'),
#     (117, 129, 'QUANTITY'),
#     (130, 136, 'INGREDIENT'),
#     (137, 151, 'QUANTITY'),
#     (152, 165, 'INGREDIENT'),
#     (166, 171, 'QUANTITY'),
#     (172, 187, 'INGREDIENT'),
#     (193, 199, 'INGREDIENT'),
#     (200, 208, 'INGREDIENT'),
#     (215, 224, 'INGREDIENT'),
#     (265, 275, 'INGREDIENT'),
#     (307, 313, 'INGREDIENT'),
#     (320, 328, 'INGREDIENT'),
#     (379, 394, 'INGREDIENT'),
#     (491, 497, 'INGREDIENT')]})]

# %%
#To be used only with small dataset

def save_training_data(data, output_file):
    nlp = spacy.blank("en")
    doc_bin = DocBin()
    for text, annotations in data:
        doc = nlp.make_doc(text)
        ents = []
        for start, end, label in annotations["entities"]:
            span = doc.char_span(start, end, label=label)
            if span is not None:
                ents.append(span)
        doc.ents = ents
        doc_bin.add(doc)
    doc_bin.to_disk(output_file)

save_training_data(train_data, 'training_data.spacy')

# %%
#To be modified/used when working with complete data

#Save in batches

import spacy
from spacy.tokens import DocBin

def save_training_data(data, output_dir, chunk_size=5000):
    """Splits data into smaller DocBins and saves each as a separate file."""
    nlp = spacy.blank("en")

    for i in range(0, len(data), chunk_size):
        doc_bin = DocBin()
        batch = data[i:i + chunk_size]  # Get a chunk of data

        for text, annotations in batch:
            doc = nlp.make_doc(text)
            ents = []
            for start, end, label in annotations["entities"]:
                span = doc.char_span(start, end, label=label)
                if span is not None:
                    ents.append(span)
            doc.ents = ents
            doc_bin.add(doc)

        output_file = f"{output_dir}/training_data_part_{i // chunk_size}.spacy"
        doc_bin.to_disk(output_file)
        print(f" Saved {output_file} with {len(batch)} samples.")

# Save training data in smaller chunks
save_training_data(train_data, 'training_data', chunk_size=5000)

# %%
#To be used when training data is saved in batches
#Load training data

import glob
import spacy
from spacy.tokens import DocBin

def load_training_data(directory):
    """Loads multiple DocBin files and merges them into a single DocBin."""
    doc_bin = DocBin()  # Create an empty DocBin

    # Load all .spacy files from the directory
    for file in glob.glob(f"{directory}/*.spacy"):
        print(f"📂 Loading {file} ...")
        temp_bin = DocBin().from_disk(file)  # Load individual file
        for doc in temp_bin.get_docs(nlp.vocab):  # Add docs to main DocBin
            doc_bin.add(doc)

    return doc_bin

# Load all training data
nlp = spacy.blank("en")  # Initialize NLP pipeline
db = load_training_data("training_data")

# %%
import random
from spacy.training import Example
from spacy.util import minibatch, compounding

# Load the training data
nlp = spacy.blank("en")
db = DocBin().from_disk("training_data.spacy")
docs = list(db.get_docs(nlp.vocab))

# Create the NER component and add it to the pipeline
if 'ner' not in nlp.pipe_names:
    ner = nlp.add_pipe("ner", last=True)

# Add the labels to the NER component
for _, annotations in train_data:
    for ent in annotations.get('entities'):
        ner.add_label(ent[2])

# Disable other pipes during training
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
with nlp.disable_pipes(*other_pipes):
    optimizer = nlp.begin_training()
    for itn in range(5):  # 5 iterations
        random.shuffle(docs)
        losses = {}
        batches = minibatch(docs, size=compounding(4.0, 32.0, 1.5))
        for batch in batches:
            for doc in batch:
                example = Example.from_dict(doc, {"entities": [(ent.start_char, ent.end_char, ent.label_) for ent in doc.ents]})
                nlp.update([example], drop=0.5, losses=losses)
        print(f"Iteration {itn}, Losses: {losses}")

# Save the trained model to disk
nlp.to_disk("ner_model")
# Out:
# Iteration 0, Losses: {'ner': 12361.166180420714}
# Iteration 1, Losses: {'ner': 4542.573362809907}
# Iteration 2, Losses: {'ner': 3426.910563268032}
# Iteration 3, Losses: {'ner': 2811.8487050707386}
# Iteration 4, Losses: {'ner': 2402.452960068132}

# %%
# Test the custom NER
doc = nlp("Add 2 cups of flour and 1 tablespoon of sugar.")
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# flour INGREDIENT
# 1 tablespoon QUANTITY
# sugar INGREDIENT

# %%
type(train_data)
# Out:
# list

# %%
def evaluate_model(model, test_data):
    examples = [Example.from_dict(nlp.make_doc(text), annotations) for text, annotations in test_data]
    scorer = model.evaluate(examples)
    return scorer

# %%
evaluation_results = evaluate_model(nlp, train_data)
print("Evaluation Results:", evaluation_results)
# Out:
# Evaluation Results: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.9617726502769766, 'ents_r': 0.9631837146394021, 'ents_f': 0.9624776652769506, 'ents_per_type': {'QUANTITY': {'p': 0.9996599217820099, 'r': 0.9994899693981639, 'f': 0.9995749383660633}, 'INGREDIENT': {'p': 0.947813557198346, 'r': 0.9497771360411827, 'f': 0.9487943306889091}}, 'speed': 26060.79946733934}

# %%
test_texts = "In a heavy 2-quart saucepan, mix 2 lbs brown sugar, nuts, evaporated milk and butter or margarine. Stir over medium heat until mixture bubbles all over top. Boil and stir 5 minutes more. Take off heat. Stir in vanilla and cereal; mix well. Using 2 teaspoons, drop and shape into 30 clusters on wax paper.Let stand until firm, about 30 minutes."
doc = nlp(test_texts)

# %%
from spacy import displacy

displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In a heavy 2-quart saucepan, mix 2 lbs
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     brown sugar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nuts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , evaporated
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     milk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     butter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  or
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     margarine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# . Stir over medium heat until mixture bubbles all over top. Boil and stir 5 minutes more. Take off heat. Stir in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vanilla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cereal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# ; mix well. Using 2 teaspoons, drop and shape into 30 clusters on wax paper.Let stand until firm, about 30 minutes.</div></span>

# %%
# Test the model on some examples
test_texts = "In a heavy 2 quart saucepan, mix 2 pound brown sugar, nuts, evaporated milk and butter or margarine. Stir over medium heat until mixture bubbles all over top. Boil and stir 5 minutes more. Take off heat. Stir in vanilla and cereal; mix well. Using 2 teaspoon, drop and shape into 30 clusters on wax paper.Let stand until firm, about 30 minutes."
doc = nlp(test_texts)

# %%
from spacy import displacy

displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In a heavy
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2 quart
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  saucepan, mix
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2 pound
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     brown sugar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nuts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# , evaporated
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     milk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     butter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  or
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     margarine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# . Stir over medium heat until mixture bubbles all over top. Boil and stir 5 minutes more. Take off heat. Stir in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vanilla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cereal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# ; mix well. Using
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2 teaspoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# , drop and shape into 30 clusters on wax paper.Let stand until firm, about 30 minutes.</div></span>

# %%
real_text = """Peel potatoes and keep aside
Heat oil in a wok
Crackle mustard seeds and urad dal
Add Kari Patta
soute 1 to 2 tablespoon ginger garlic paste and chopped onion
Aad potatoes and soute for 1 to 2minutes
Add all dry masala
Cook with lid on slow flame for 10 minutes
Garnish with chopped coriander
Serve hot with roti or poori
"""

# %%
doc2 = nlp(real_text)

displacy.render(doc2, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Peel
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     potatoes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  and keep aside<br>Heat
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     oil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  in a wok<br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Crackle mustard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  seeds and urad dal<br>Add Kari
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Patta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# <br>soute 1 to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2 tablespoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ginger garlic paste
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  and chopped
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     onion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# <br>Aad
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     potatoes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
#  and soute for 1 to 2minutes<br>Add all dry masala<br>Cook with lid on slow flame for 10 minutes<br>Garnish with chopped coriander<br>Serve hot with roti or
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     poori
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">INGREDIENT</span>
# </mark>
# <br></div></span>

# %%
import json


entities = []
for ent in doc.ents:
    if ent.label_ == "QUANTITY":
        for i_ent in doc.ents:
            if i_ent.label_ == "INGREDIENT" and i_ent.start == ent.end:
                entities.append({"ingredient": i_ent.text, "quantity": ent.text})
                break
    elif ent.label_ == "INGREDIENT":
        if not any(e["ingredient"] == ent.text for e in entities):
            entities.append({"ingredient": ent.text, "quantity": ""})

entities_json = json.dumps(entities, indent=2)

print(entities_json)
# Out:
# [
#   {
#     "ingredient": "brown sugar",
#     "quantity": ""
#   },
#   {
#     "ingredient": "nuts",
#     "quantity": ""
#   },
#   {
#     "ingredient": "milk",
#     "quantity": ""
#   },
#   {
#     "ingredient": "butter",
#     "quantity": ""
#   },
#   {
#     "ingredient": "margarine",
#     "quantity": ""
#   },
#   {
#     "ingredient": "vanilla",
#     "quantity": ""
#   },
#   {
#     "ingredient": "cereal",
#     "quantity": ""
#   }
# ]
